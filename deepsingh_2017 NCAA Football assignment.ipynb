# %% [markdown]
# # Football Assignment
# In this project, you will use the skills and concepts we discussed this semester to ingest, manipulate, analyze, and report data using Python.
#
# Some of the more helpful concepts could be used to complete this notebook:
# * basic syntax, len() function, variables
# * conditionals
# * looping
# * data structures: lists, dictionaries, and sets
# * pandas
# * regex - this is helpful to get text patterns
# * JSON - reading and writing JSON files
# * Pathlib for accessing the files, regex (if desired)
#
# You have been provided a set of JSON files describing football games from the 2017 season. The files may or may not include all the games from that season. If a statistic in the provided data conflicts with *actual* real-world data, the correct answer is in the *provided* data.
#
# Use only the JSON files contained in the 'Full' folders (not 'Flattended').
#
# The objective of this project is to answer the set of questions below. Your project's output is a JSON file containing the question (key) and the answer (value). The keys must be in the format qn, and the answer must be a value appropriate for the question.
#
# The 'season' includes all games provided (including bowl games).

# %%
# Example of how to answer a question
answer_file = {} # create blank dictionary
answer_file['q1'] = 'yes' # Answer 'yes' to Question 1
print(answer_file)
# Out:
# {'q1': 'yes'}

# %% [markdown]
# > You must name the file 'mis501_python_project_*netid*.json', for example, mis511_python_project_gjbott.json.

# %%
#Import statements
import json
import pathlib
import os
import re

#define a function to load the contents of a json file
def load_json(json_path):
    payload = None
    #error handling
    try:
        with open(json_path) as fin:
            payload = json.load(fin)
    except:
        pass
    
    return payload

# %% [markdown]
# ### All Games

# %%
#Create a Path object
cwd_path = pathlib.Path()
cwd_path.cwd()
#Path to all regular season games
#path = "**/full/Week*/*json"
#Path to all games in the season
path = "**/full/**/*json"
#create a blank list to store the file path of all games
all_game_files = []

#find all games and add them to a list
new_files = list(cwd_path.rglob(path))
all_game_files.extend(new_files)

#create a dictionary with week as the key and file path as the value
all_game_dict = {file.parts[2]: file for file in all_game_files}

# %%
all_game_list = []
for file in all_game_files:
    all_game_list += [file.parts[2]]
all_game_list
# Out:
# ['400953322 - North Texas vs Troy.json',
#  '400953323 - Oregon vs Boise State.json',
#  '400953324 - Colorado State vs Marshall.json',
#  '400953325 - Arkansas State vs Middle Tennessee.json',
#  '400953386 - Florida Atlantic vs Akron.json',
#  '400953387 - Florida Intl vs Temple.json',
#  '400953388 - Ohio vs UAB.json',
#  '400953389 - Wyoming vs Central Michigan.json',
#  '400953390 - South Florida vs Texas Tech.json',
#  '400953391 - Army vs San Diego State.json',
#  '400953392 - Toledo vs Appalachian State.json',
#  '400953393 - Houston vs Fresno State.json',
#  '400953394 - Northern Illinois vs Duke.json',
#  '400953395 - West Virginia vs Utah.json',
#  '400953396 - UCLA vs Kansas State.json',
#  '400953397 - Florida State vs Southern Mississippi.json',
#  '400953398 - Boston College vs Iowa.json',
#  '400953399 - Missouri vs Texas.json',
#  '400953400 - Navy vs Virginia.json',
#  '400953401 - TCU vs Stanford.json',
#  '400953402 - Texas A_M vs Wake Forest.json',
#  '400953403 - Northwestern vs Kentucky.json',
#  '400953404 - Ohio State vs USC.json',
#  '400953405 - Mississippi State vs Louisville.json',
#  '400953406 - Memphis vs Iowa State.json',
#  '400953407 - Penn State vs Washington.json',
#  '400953408 - Miami vs Wisconsin.json',
#  '400953409 - Georgia State vs Western Kentucky.json',
#  '400953410 - South Carolina vs Michigan.json',
#  '400953411 - Auburn vs UCF.json',
#  '400953412 - Oklahoma vs Georgia.json',
#  '400953413 - Clemson vs Alabama.json',
#  '400953414 - LSU vs Notre Dame.json',
#  '400953415 - Georgia vs Alabama.json',
#  '400953416 - Oklahoma State vs Virginia Tech.json',
#  '400953417 - Arizona State vs NC State.json',
#  '400954523 - SMU vs Louisiana Tech.json',
#  '400959397 - Michigan State vs Washington State.json',
#  '400959398 - Purdue vs Arizona.json',
#  '400966332 - Utah State vs New Mexico State.json',
#  '400933827 - Alabama vs Florida State.json',
#  '400933828 - Arkansas vs Florida A_M.json',
#  '400933829 - Auburn vs Georgia Southern.json',
#  '400933830 - Florida vs Michigan.json',
#  '400933831 - Georgia vs Appalachian State.json',
#  '400933832 - Southern Mississippi vs Kentucky.json',
#  '400933833 - LSU vs BYU.json',
#  '400933834 - Ole Miss vs South Alabama.json',
#  '400933835 - Mississippi State vs Charleston Southern.json',
#  '400933836 - Missouri vs Missouri State.json',
#  '400933837 - South Carolina vs NC State.json',
#  '400933838 - UCLA vs Texas A_M.json',
#  '400933839 - Middle Tennessee vs Vanderbilt.json',
#  '400933840 - Georgia Tech vs Tennessee.json',
#  '400934488 - Iowa State vs Northern Iowa.json',
#  '400934489 - Baylor vs Liberty.json',
#  '400934490 - Kansas vs Southeast Missouri State.json',
#  '400934491 - Kansas State vs Central Arkansas.json',
#  '400934492 - Oklahoma vs UTEP.json',
#  '400934493 - Oklahoma State vs Tulsa.json',
#  '400934494 - TCU vs Jackson State.json',
#  '400934495 - Texas vs Maryland.json',
#  '400934496 - Texas Tech vs Eastern Washington.json',
#  '400934497 - Virginia Tech vs West Virginia.json',
#  '400934570 - Army vs Fordham.json',
#  '400934573 - Notre Dame vs Temple.json',
#  '400935229 - Indiana vs Ohio State.json',
#  '400935230 - Minnesota vs Buffalo.json',
#  '400935231 - Wisconsin vs Utah State.json',
#  '400935232 - Illinois vs Ball State.json',
#  '400935233 - Iowa vs Wyoming.json',
#  '400935234 - Michigan State vs Bowling Green.json',
#  '400935235 - Nebraska vs Arkansas State.json',
#  '400935236 - Northwestern vs Nevada.json',
#  '400935237 - Penn State vs Akron.json',
#  '400935238 - Purdue vs Louisville.json',
#  '400935247 - Arizona State vs New Mexico State.json',
#  '400935248 - Utah vs North Dakota.json',
#  '400935249 - Colorado vs Colorado State.json',
#  '400935250 - Rutgers vs Washington.json',
#  '400935251 - Arizona vs Northern Arizona.json',
#  '400935252 - USC vs Western Michigan.json',
#  '400935253 - Oregon vs Southern Utah.json',
#  '400935254 - Oregon State vs Portland State.json',
#  '400935255 - Washington State vs Montana State.json',
#  '400935256 - North Carolina vs California.json',
#  '400935257 - Rice vs Stanford.json',
#  '400935282 - Colorado State vs Oregon State.json',
#  '400937445 - Wake Forest vs Presbyterian College.json',
#  '400937446 - Northern Illinois vs Boston College.json',
#  '400937447 - Clemson vs Kent State.json',
#  '400937448 - Duke vs North Carolina Central.json',
#  '400937449 - Miami vs Bethune-Cookman.json',
#  '400937450 - Pittsburgh vs Youngstown State.json',
#  '400937451 - Syracuse vs Central Connecticut.json',
#  '400937452 - Virginia vs William _ Mary.json',
#  '400938591 - UCF vs Florida Intl.json',
#  '400938592 - Florida Atlantic vs Navy.json',
#  '400938593 - Louisiana Tech vs Northwestern State.json',
#  '400938594 - Marshall vs Miami (OH).json',
#  '400938595 - North Texas vs Lamar.json',
#  '400938596 - Old Dominion vs Albany.json',
#  '400938597 - UAB vs Alabama A_M.json',
#  '400938599 - Western Kentucky vs Eastern Kentucky.json',
#  '400938887 - UMass vs Hawai_i.json',
#  '400938888 - Coastal Carolina vs UMass.json',
#  '400941786 - San Jose╠ü State vs South Florida.json',
#  '400941787 - Cincinnati vs Austin Peay.json',
#  '400941788 - Connecticut vs Holy Cross.json',
#  '400941789 - Memphis vs Louisiana Monroe.json',
#  '400941790 - East Carolina vs James Madison.json',
#  '400941791 - South Florida vs Stony Brook.json',
#  '400941792 - SMU vs Stephen F. Austin.json',
#  '400941793 - Tulane vs Grambling.json',
#  '400944826 - Georgia State vs Tennessee State.json',
#  '400944827 - Idaho vs Sacramento State.json',
#  '400944829 - Texas State vs Houston Baptist.json',
#  '400944830 - Boise State vs Troy.json',
#  '400944889 - Toledo vs Elon.json',
#  '400944890 - Central Michigan vs Rhode Island.json',
#  '400944891 - Eastern Michigan vs Charlotte.json',
#  '400944892 - Ohio vs Hampton.json',
#  '400945031 - BYU vs Portland State.json',
#  '400945246 - Air Force vs VMI.json',
#  '400945247 - New Mexico vs Abilene Christian.json',
#  '400945248 - Fresno State vs Incarnate Word.json',
#  '400945249 - Hawai_i vs Western Carolina.json',
#  '400945250 - San Diego State vs UC Davis.json',
#  '400945251 - San Jose╠ü State vs Cal Poly.json',
#  '400945252 - UNLV vs Howard.json',
#  '400933904 - Alabama vs LSU.json',
#  '400933905 - Arkansas vs Coastal Carolina.json',
#  '400933906 - Georgia vs South Carolina.json',
#  '400933907 - Kentucky vs Ole Miss.json',
#  '400933908 - Mississippi State vs UMass.json',
#  '400933909 - Missouri vs Florida.json',
#  '400933910 - Tennessee vs Southern Mississippi.json',
#  '400933911 - Texas A_M vs Auburn.json',
#  '400933912 - Vanderbilt vs Western Kentucky.json',
#  '400934541 - Kansas vs Baylor.json',
#  '400934542 - West Virginia vs Iowa State.json',
#  '400934543 - Texas Tech vs Kansas State.json',
#  '400934544 - Oklahoma State vs Oklahoma.json',
#  '400934545 - TCU vs Texas.json',
#  '400934569 - Air Force vs Army.json',
#  '400934580 - Notre Dame vs Wake Forest.json',
#  '400935310 - Utah vs UCLA.json',
#  '400935311 - USC vs Arizona.json',
#  '400935312 - Arizona State vs Colorado.json',
#  '400935313 - Washington vs Oregon.json',
#  '400935314 - California vs Oregon State.json',
#  '400935315 - Washington State vs Stanford.json',
#  '400935396 - Indiana vs Wisconsin.json',
#  '400935397 - Iowa vs Ohio State.json',
#  '400935398 - Michigan vs Minnesota.json',
#  '400935399 - Michigan State vs Penn State.json',
#  '400935400 - Nebraska vs Northwestern.json',
#  '400935401 - Purdue vs Illinois.json',
#  '400935402 - Rutgers vs Maryland.json',
#  '400937510 - NC State vs Clemson.json',
#  '400937511 - Florida State vs Syracuse.json',
#  '400937512 - Virginia vs Georgia Tech.json',
#  '400937513 - Miami vs Virginia Tech.json',
#  '400938649 - Old Dominion vs Charlotte.json',
#  '400938650 - Florida Intl vs UT San Antonio.json',
#  '400938651 - Louisiana Tech vs North Texas.json',
#  '400938652 - Middle Tennessee vs UTEP.json',
#  '400938653 - UAB vs Rice.json',
#  '400938675 - Florida Atlantic vs Marshall.json',
#  '400941833 - Houston vs East Carolina.json',
#  '400941834 - Temple vs Navy.json',
#  '400941835 - Tulsa vs Memphis.json',
#  '400941836 - SMU vs UCF.json',
#  '400941837 - Tulane vs Cincinnati.json',
#  '400944866 - Troy vs Idaho.json',
#  '400944867 - Louisiana Monroe vs Appalachian State.json',
#  '400944868 - Georgia Southern vs Georgia State.json',
#  '400944869 - South Alabama vs Louisiana.json',
#  '400944870 - Texas State vs New Mexico State.json',
#  '400945008 - Kent State vs Bowling Green.json',
#  '400945009 - Ohio vs Miami (OH).json',
#  '400945010 - Western Michigan vs Central Michigan.json',
#  '400945011 - Eastern Michigan vs Ball State.json',
#  '400945012 - Toledo vs Northern Illinois.json',
#  '400945289 - Boise State vs Nevada.json',
#  '400945290 - Wyoming vs Colorado State.json',
#  '400945291 - New Mexico vs Utah State.json',
#  '400945292 - Fresno State vs BYU.json',
#  '400945293 - UNLV vs Hawai_i.json',
#  '400945294 - San Jose State vs San Diego State.json',
#  '400985386 - Connecticut vs South Florida.json',
#  '400933913 - Auburn vs Georgia.json',
#  '400933914 - LSU vs Arkansas.json',
#  '400933915 - Ole Miss vs Louisiana.json',
#  '400933916 - Mississippi State vs Alabama.json',
#  '400933917 - Missouri vs Tennessee.json',
#  '400933918 - South Carolina vs Florida.json',
#  '400933919 - Texas A_M vs New Mexico.json',
#  '400933920 - Vanderbilt vs Kentucky.json',
#  '400934546 - Texas vs Kansas.json',
#  '400934547 - Kansas State vs West Virginia.json',
#  '400934548 - Iowa State vs Oklahoma State.json',
#  '400934549 - Baylor vs Texas Tech.json',
#  '400934550 - Oklahoma vs TCU.json',
#  '400934565 - Army vs Duke.json',
#  '400934581 - Miami vs Notre Dame.json',
#  '400935316 - Stanford vs Washington.json',
#  '400935317 - Arizona vs Oregon State.json',
#  '400935318 - UCLA vs Arizona State.json',
#  '400935319 - Colorado vs USC.json',
#  '400935320 - Utah vs Washington State.json',
#  '400935403 - Illinois vs Indiana.json',
#  '400935404 - Maryland vs Michigan.json',
#  '400935405 - Minnesota vs Nebraska.json',
#  '400935406 - Northwestern vs Purdue.json',
#  '400935407 - Ohio State vs Michigan State.json',
#  '400935408 - Penn State vs Rutgers.json',
#  '400935409 - Wisconsin vs Iowa.json',
#  '400937514 - Pittsburgh vs North Carolina.json',
#  '400937515 - Boston College vs NC State.json',
#  '400937516 - Clemson vs Florida State.json',
#  '400937517 - Georgia Tech vs Virginia Tech.json',
#  '400937518 - Louisville vs Virginia.json',
#  '400937519 - Syracuse vs Wake Forest.json',
#  '400938654 - Charlotte vs Middle Tennessee.json',
#  '400938655 - Florida Intl vs Old Dominion.json',
#  '400938656 - Louisiana Tech vs Florida Atlantic.json',
#  '400938657 - Marshall vs Western Kentucky.json',
#  '400938658 - North Texas vs UTEP.json',
#  '400938659 - Rice vs Southern Mississippi.json',
#  '400938660 - UT San Antonio vs UAB.json',
#  '400938894 - UMass vs Maine.json',
#  '400941840 - Cincinnati vs Temple.json',
#  '400941841 - Navy vs SMU.json',
#  '400941842 - UCF vs Connecticut.json',
#  '400941843 - East Carolina vs Tulane.json',
#  '400944871 - Appalachian State vs Georgia Southern.json',
#  '400944872 - South Alabama vs Arkansas State.json',
#  '400944873 - Texas State vs Georgia State.json',
#  '400944874 - Coastal Carolina vs Troy.json',
#  '400945013 - Miami (OH) vs Akron.json',
#  '400945014 - Buffalo vs Bowling Green.json',
#  '400945015 - Central Michigan vs Eastern Michigan.json',
#  '400945016 - Western Michigan vs Kent State.json',
#  '400945017 - Ohio vs Toledo.json',
#  '400945018 - Northern Illinois vs Ball State.json',
#  '400945295 - Air Force vs Wyoming.json',
#  '400945296 - Colorado State vs Boise State.json',
#  '400945297 - Hawai_i vs Fresno State.json',
#  '400945298 - Nevada vs San Jose State.json',
#  '400945299 - UNLV vs BYU.json',
#  '400933921 - Alabama vs Mercer.json',
#  '400933922 - Arkansas vs Mississippi State.json',
#  '400933923 - Auburn vs Louisiana Monroe.json',
#  '400933924 - Florida vs UAB.json',
#  '400933925 - Georgia vs Kentucky.json',
#  '400933926 - Ole Miss vs Texas A_M.json',
#  '400933927 - South Carolina vs Wofford.json',
#  '400933928 - Tennessee vs LSU.json',
#  '400933929 - Vanderbilt vs Missouri.json',
#  '400934551 - Baylor vs Iowa State.json',
#  '400934552 - Oklahoma State vs Kansas State.json',
#  '400934553 - Kansas vs Oklahoma.json',
#  '400934554 - West Virginia vs Texas.json',
#  '400934555 - Texas Tech vs TCU.json',
#  '400934571 - North Texas vs Army.json',
#  '400934582 - Notre Dame vs Navy.json',
#  '400935321 - Oregon vs Arizona.json',
#  '400935322 - Oregon State vs Arizona State.json',
#  '400935323 - USC vs UCLA.json',
#  '400935324 - Washington vs Utah.json',
#  '400935325 - Stanford vs California.json',
#  '400935410 - Indiana vs Rutgers.json',
#  '400935411 - Iowa vs Purdue.json',
#  '400935412 - Michigan State vs Maryland.json',
#  '400935413 - Northwestern vs Minnesota.json',
#  '400935414 - Ohio State vs Illinois.json',
#  '400935415 - Penn State vs Nebraska.json',
#  '400935416 - Wisconsin vs Michigan.json',
#  '400937520 - Connecticut vs Boston College.json',
#  '400937521 - Clemson vs The Citadel.json',
#  '400937522 - Duke vs Georgia Tech.json',
#  '400937523 - Florida State vs Delaware State.json',
#  '400937524 - Louisville vs Syracuse.json',
#  '400937525 - Miami vs Virginia.json',
#  '400937526 - North Carolina vs Western Carolina.json',
#  '400937527 - Wake Forest vs NC State.json',
#  '400937528 - Virginia Tech vs Pittsburgh.json',
#  '400938661 - Southern Mississippi vs Charlotte.json',
#  '400938662 - Florida Atlantic vs Florida Intl.json',
#  '400938663 - UTEP vs Louisiana Tech.json',
#  '400938664 - UT San Antonio vs Marshall.json',
#  '400938665 - Western Kentucky vs Middle Tennessee.json',
#  '400938666 - Old Dominion vs Rice.json',
#  '400938895 - BYU vs UMass.json',
#  '400941844 - Temple vs UCF.json',
#  '400941845 - East Carolina vs Cincinnati.json',
#  '400941846 - Tulane vs Houston.json',
#  '400941847 - Memphis vs SMU.json',
#  '400941848 - South Florida vs Tulsa.json',
#  '400944875 - Arkansas State vs Texas State.json',
#  '400944876 - Idaho vs Coastal Carolina.json',
#  '400944877 - Georgia Southern vs South Alabama.json',
#  '400944878 - Louisiana vs New Mexico State.json',
#  '400945019 - Kent State vs Central Michigan.json',
#  '400945020 - Akron vs Ohio.json',
#  '400945021 - Miami (OH) vs Eastern Michigan.json',
#  '400945022 - Bowling Green vs Toledo.json',
#  '400945023 - Northern Illinois vs Western Michigan.json',
#  '400945024 - Ball State vs Buffalo.json',
#  '400945300 - Boise State vs Air Force.json',
#  '400945301 - Colorado State vs San Jose State.json',
#  '400945302 - New Mexico vs UNLV.json',
#  '400945303 - Utah State vs Hawai_i.json',
#  '400945304 - Wyoming vs Fresno State.json',
#  '400945305 - San Diego State vs Nevada.json',
#  '400933930 - Mississippi State vs Ole Miss.json',
#  '400933931 - Arkansas vs Missouri.json',
#  '400933932 - Auburn vs Alabama.json',
#  '400933933 - Florida vs Florida State.json',
#  '400933934 - Georgia Tech vs Georgia.json',
#  '400933935 - Kentucky vs Louisville.json',
#  '400933936 - LSU vs Texas A_M.json',
#  '400933937 - South Carolina vs Clemson.json',
#  '400933938 - Tennessee vs Vanderbilt.json',
#  '400934556 - TCU vs Baylor.json',
#  '400934557 - Texas vs Texas Tech.json',
#  '400934558 - Kansas State vs Iowa State.json',
#  '400934559 - Oklahoma State vs Kansas.json',
#  '400934560 - Oklahoma vs West Virginia.json',
#  '400934583 - Stanford vs Notre Dame.json',
#  '400935326 - UCLA vs California.json',
#  '400935327 - Oregon vs Oregon State.json',
#  '400935328 - Arizona State vs Arizona.json',
#  '400935329 - Utah vs Colorado.json',
#  '400935330 - Washington vs Washington State.json',
#  '400935417 - Nebraska vs Iowa.json',
#  '400935418 - Illinois vs Northwestern.json',
#  '400935419 - Maryland vs Penn State.json',
#  '400935420 - Michigan vs Ohio State.json',
#  '400935421 - Minnesota vs Wisconsin.json',
#  '400935422 - Purdue vs Indiana.json',
#  '400935423 - Rutgers vs Michigan State.json',
#  '400937529 - Pittsburgh vs Miami.json',
#  '400937530 - Virginia vs Virginia Tech.json',
#  '400937531 - Syracuse vs Boston College.json',
#  '400937532 - Wake Forest vs Duke.json',
#  '400937533 - NC State vs North Carolina.json',
#  '400938667 - Charlotte vs Florida Atlantic.json',
#  '400938668 - Florida Intl vs Western Kentucky.json',
#  '400938669 - Louisiana Tech vs UT San Antonio.json',
#  '400938670 - Marshall vs Southern Mississippi.json',
#  '400938671 - Middle Tennessee vs Old Dominion.json',
#  '400938672 - Rice vs North Texas.json',
#  '400938673 - UAB vs UTEP.json',
#  '400941849 - UCF vs South Florida.json',
#  '400941850 - Houston vs Navy.json',
#  '400941851 - Cincinnati vs Connecticut.json',
#  '400941852 - Memphis vs East Carolina.json',
#  '400941853 - Tulsa vs Temple.json',
#  '400941854 - SMU vs Tulane.json',
#  '400944879 - Georgia State vs Appalachian State.json',
#  '400944880 - Louisiana Monroe vs Arkansas State.json',
#  '400944881 - Louisiana vs Georgia Southern.json',
#  '400944882 - New Mexico State vs Idaho.json',
#  '400944883 - Troy vs Texas State.json',
#  '400945025 - Eastern Michigan vs Bowling Green.json',
#  '400945026 - Akron vs Kent State.json',
#  '400945027 - Ball State vs Miami (OH).json',
#  '400945028 - Central Michigan vs Northern Illinois.json',
#  '400945029 - Buffalo vs Ohio.json',
#  '400945030 - Toledo vs Western Michigan.json',
#  '400945306 - Air Force vs Utah State.json',
#  '400945307 - Fresno State vs Boise State.json',
#  '400945308 - San Diego State vs New Mexico.json',
#  '400945309 - San Jose State vs Wyoming.json',
#  '400945310 - Hawai_i vs BYU.json',
#  '400945311 - Nevada vs UNLV.json',
#  '400944884 - Appalachian State vs Louisiana.json',
#  '400944885 - Arkansas State vs Troy.json',
#  '400944886 - Coastal Carolina vs Georgia Southern.json',
#  '400944887 - Georgia State vs Idaho.json',
#  '400944888 - New Mexico State vs South Alabama.json',
#  '400955149 - USC vs Stanford.json',
#  '400955150 - Toledo vs Akron.json',
#  '400955151 - UCF vs Memphis.json',
#  '400955152 - Florida Atlantic vs North Texas.json',
#  '400955153 - Auburn vs Georgia.json',
#  '400955154 - Boise State vs Fresno State.json',
#  '400955155 - Clemson vs Miami.json',
#  '400955156 - Wisconsin vs Ohio State.json',
#  '400955157 - Oklahoma vs TCU.json',
#  '400985387 - Florida Intl vs UMass.json',
#  '401000149 - Florida State vs Louisiana Monroe.json',
#  '400934572 - Navy vs Army.json',
#  '400933841 - Alabama vs Fresno State.json',
#  '400933842 - Arkansas vs TCU.json',
#  '400933843 - Clemson vs Auburn.json',
#  '400933845 - Notre Dame vs Georgia.json',
#  '400933846 - Kentucky vs Eastern Kentucky.json',
#  '400933847 - LSU vs Chattanooga.json',
#  '400933848 - Ole Miss vs UT Martin.json',
#  '400933849 - Louisiana Tech vs Mississippi State.json',
#  '400933850 - Missouri vs South Carolina.json',
#  '400933851 - Tennessee vs Indiana State.json',
#  '400933852 - Texas A_M vs Nicholls.json',
#  '400933853 - Vanderbilt vs Alabama A_M.json',
#  '400934498 - Baylor vs UT San Antonio.json',
#  '400934499 - Iowa State vs Iowa.json',
#  '400934500 - Kansas vs Central Michigan.json',
#  '400934501 - Kansas State vs Charlotte.json',
#  '400934502 - Ohio State vs Oklahoma.json',
#  '400934503 - South Alabama vs Oklahoma State.json',
#  '400934504 - Texas vs San Jose╠ü State.json',
#  '400934505 - West Virginia vs East Carolina.json',
#  '400934562 - Army vs Buffalo.json',
#  '400935240 - Duke vs Northwestern.json',
#  '400935241 - Illinois vs Western Kentucky.json',
#  '400935242 - Maryland vs Towson.json',
#  '400935243 - Michigan vs Cincinnati.json',
#  '400935244 - Michigan State vs Western Michigan.json',
#  '400935245 - Penn State vs Pittsburgh.json',
#  '400935246 - Rutgers vs Eastern Michigan.json',
#  '400935258 - Arizona vs Houston.json',
#  '400935259 - Arizona State vs San Diego State.json',
#  '400935260 - USC vs Stanford.json',
#  '400935261 - UCLA vs Hawai_i.json',
#  '400935262 - Colorado vs Texas State.json',
#  '400935263 - BYU vs Utah.json',
#  '400935264 - Oregon vs Nebraska.json',
#  '400935265 - Oregon State vs Minnesota.json',
#  '400935266 - Washington vs Montana.json',
#  '400935267 - Washington State vs Boise State.json',
#  '400935268 - California vs Weber State.json',
#  '400935347 - Virginia vs Indiana.json',
#  '400935348 - Wisconsin vs Florida Atlantic.json',
#  '400937453 - Boston College vs Wake Forest.json',
#  '400937455 - Georgia Tech vs Jacksonville State.json',
#  '400937456 - North Carolina vs Louisville.json',
#  '400937458 - NC State vs Marshall.json',
#  '400937459 - Syracuse vs Middle Tennessee.json',
#  '400937460 - Virginia Tech vs Delaware.json',
#  '400938600 - Florida Intl vs Alcorn State.json',
#  '400938601 - SMU vs North Texas.json',
#  '400938602 - UMass vs Old Dominion.json',
#  '400938603 - UTEP vs Rice.json',
#  '400938604 - Southern Mississippi vs Southern.json',
#  '400938605 - Ball State vs UAB.json',
#  '400941797 - Temple vs Villanova.json',
#  '400941798 - Tulsa vs Louisiana.json',
#  '400944831 - Appalachian State vs Savannah State.json',
#  '400944832 - Georgia Southern vs New Hampshire.json',
#  '400944833 - Idaho vs UNLV.json',
#  '400944834 - New Mexico vs New Mexico State.json',
#  '400944835 - Troy vs Alabama State.json',
#  '400944893 - Akron vs Arkansas-Pine Bluff.json',
#  '400944894 - Miami (OH) vs Austin Peay.json',
#  '400944895 - Northern Illinois vs Eastern Illinois.json',
#  '400944896 - Kent State vs Howard.json',
#  '400944897 - Bowling Green vs South Dakota.json',
#  '400944898 - Nevada vs Toledo.json',
#  '400945253 - Utah State vs Idaho State.json',
#  '400945254 - Colorado State vs Abilene Christian.json',
#  '400945255 - Wyoming vs Gardner-Webb.json',
#  '400933854 - Alabama vs Colorado State.json',
#  '400933855 - Auburn vs Mercer.json',
#  '400933856 - Florida vs Tennessee.json',
#  '400933857 - Georgia vs Samford.json',
#  '400933858 - California vs Ole Miss.json',
#  '400933859 - Mississippi State vs LSU.json',
#  '400933860 - Missouri vs Purdue.json',
#  '400933861 - South Carolina vs Kentucky.json',
#  '400933862 - Texas A_M vs Louisiana.json',
#  '400933863 - Vanderbilt vs Kansas State.json',
#  '400934506 - Duke vs Baylor.json',
#  '400934507 - Ohio vs Kansas.json',
#  '400934508 - Oklahoma vs Tulane.json',
#  '400934509 - Pittsburgh vs Oklahoma State.json',
#  '400934510 - TCU vs SMU.json',
#  '400934511 - USC vs Texas.json',
#  '400934512 - Texas Tech vs Arizona State.json',
#  '400934513 - West Virginia vs Delaware State.json',
#  '400934517 - Akron vs Iowa State.json',
#  '400934563 - Ohio State vs Army.json',
#  '400934574 - Boston College vs Notre Dame.json',
#  '400935269 - UTEP vs Arizona.json',
#  '400935270 - Memphis vs UCLA.json',
#  '400935271 - Colorado vs Northern Colorado.json',
#  '400935272 - Utah vs San Jose╠ü State.json',
#  '400935273 - Wyoming vs Oregon.json',
#  '400935274 - Washington State vs Oregon State.json',
#  '400935275 - Washington vs Fresno State.json',
#  '400935276 - San Diego State vs Stanford.json',
#  '400935349 - BYU vs Wisconsin.json',
#  '400935351 - Iowa vs North Texas.json',
#  '400935352 - Michigan vs Air Force.json',
#  '400935353 - Minnesota vs Middle Tennessee.json',
#  '400935354 - Nebraska vs Northern Illinois.json',
#  '400935355 - Northwestern vs Bowling Green.json',
#  '400935356 - Penn State vs Georgia State.json',
#  '400935357 - Rutgers vs Morgan State.json',
#  '400937461 - Louisville vs Clemson.json',
#  '400937464 - Old Dominion vs North Carolina.json',
#  '400937465 - NC State vs Furman.json',
#  '400937466 - Syracuse vs Central Michigan.json',
#  '400937467 - Virginia vs Connecticut.json',
#  '400937468 - East Carolina vs Virginia Tech.json',
#  '400937469 - Wake Forest vs Utah State.json',
#  '400938606 - Charlotte vs North Carolina A_T.json',
#  '400938607 - Florida Atlantic vs Bethune-Cookman.json',
#  '400938608 - Western Kentucky vs Louisiana Tech.json',
#  '400938609 - Marshall vs Kent State.json',
#  '400938610 - Houston vs Rice.json',
#  '400938611 - Louisiana Monroe vs Southern Mississippi.json',
#  '400938612 - UAB vs Coastal Carolina.json',
#  '400938613 - UT San Antonio vs Southern.json',
#  '400941799 - South Florida vs Illinois.json',
#  '400941800 - Temple vs UMass.json',
#  '400941801 - Miami (OH) vs Cincinnati.json',
#  '400941802 - Toledo vs Tulsa.json',
#  '400944836 - Texas State vs Appalachian State.json',
#  '400944837 - New Mexico State vs Troy.json',
#  '400944838 - Arkansas State vs Arkansas-Pine Bluff.json',
#  '400944839 - Western Michigan vs Idaho.json',
#  '400944840 - South Alabama vs Alabama A_M.json',
#  '400944899 - Buffalo vs Colgate.json',
#  '400944900 - Ball State vs Tennessee Tech.json',
#  '400945256 - Boise State vs New Mexico.json',
#  '400945257 - Nevada vs Idaho State.json',
#  '400933864 - Arkansas vs Texas A_M.json',
#  '400933865 - Georgia vs Mississippi State.json',
#  '400933866 - Kentucky vs Florida.json',
#  '400933867 - LSU vs Syracuse.json',
#  '400933868 - Missouri vs Auburn.json',
#  '400933869 - South Carolina vs Louisiana Tech.json',
#  '400933870 - Tennessee vs UMass.json',
#  '400933871 - Vanderbilt vs Alabama.json',
#  '400934514 - Kansas vs West Virginia.json',
#  '400934515 - Baylor vs Oklahoma.json',
#  '400934516 - Oklahoma State vs TCU.json',
#  '400934518 - Houston vs Texas Tech.json',
#  '400934561 - Tulane vs Army.json',
#  '400934575 - Michigan State vs Notre Dame.json',
#  '400935277 - Arizona vs Utah.json',
#  '400935278 - Arizona State vs Oregon.json',
#  '400935279 - California vs USC.json',
#  '400935280 - Stanford vs UCLA.json',
#  '400935281 - Colorado vs Washington.json',
#  '400935283 - Washington State vs Nevada.json',
#  '400935359 - Indiana vs Georgia Southern.json',
#  '400935360 - Iowa vs Penn State.json',
#  '400935361 - Maryland vs UCF.json',
#  '400935362 - Nebraska vs Rutgers.json',
#  '400935363 - Ohio State vs UNLV.json',
#  '400935364 - Purdue vs Michigan.json',
#  '400937470 - Clemson vs Boston College.json',
#  '400937471 - North Carolina vs Duke.json',
#  '400937472 - Florida State vs NC State.json',
#  '400937473 - Georgia Tech vs Pittsburgh.json',
#  '400937474 - Louisville vs Kent State.json',
#  '400937475 - Miami vs Toledo.json',
#  '400937477 - Virginia Tech vs Old Dominion.json',
#  '400937478 - Appalachian State vs Wake Forest.json',
#  '400938614 - Charlotte vs Georgia State.json',
#  '400938615 - Rice vs Florida Intl.json',
#  '400938616 - Buffalo vs Florida Atlantic.json',
#  '400938617 - Middle Tennessee vs Bowling Green.json',
#  '400938618 - North Texas vs UAB.json',
#  '400938619 - New Mexico State vs UTEP.json',
#  '400938620 - Texas State vs UT San Antonio.json',
#  '400938621 - Western Kentucky vs Ball State.json',
#  '400941803 - South Florida vs Temple.json',
#  '400941804 - Navy vs Cincinnati.json',
#  '400941805 - Memphis vs Southern Illinois.json',
#  '400941806 - SMU vs Arkansas State.json',
#  '400941807 - Tulsa vs New Mexico.json',
#  '400941838 - Connecticut vs East Carolina.json',
#  '400944818 - Troy vs Akron.json',
#  '400944841 - South Alabama vs Idaho.json',
#  '400944842 - Louisiana vs Louisiana Monroe.json',
#  '400944843 - Coastal Carolina vs Western Illinois.json',
#  '400944901 - Central Michigan vs Miami (OH).json',
#  '400944902 - Eastern Michigan vs Ohio.json',
#  '400944903 - Western Michigan vs Wagner.json',
#  '400945258 - Boise State vs Virginia.json',
#  '400945259 - Air Force vs San Diego State.json',
#  '400945260 - San Jose╠ü State vs Utah State.json',
#  '400945261 - Wyoming vs Hawai_i.json',
#  '400933872 - Alabama vs Ole Miss.json',
#  '400933873 - Arkansas vs New Mexico State.json',
#  '400933874 - Auburn vs Mississippi State.json',
#  '400933875 - Florida vs Vanderbilt.json',
#  '400933876 - Kentucky vs Eastern Michigan.json',
#  '400933877 - LSU vs Troy.json',
#  '400933878 - Tennessee vs Georgia.json',
#  '400933879 - Texas A_M vs South Carolina.json',
#  '400934519 - Kansas State vs Baylor.json',
#  '400934520 - Texas Tech vs Oklahoma State.json',
#  '400934521 - Iowa State vs Texas.json',
#  '400934566 - Army vs UTEP.json',
#  '400934576 - Notre Dame vs Miami (OH).json',
#  '400935284 - Washington State vs USC.json',
#  '400935285 - Stanford vs Arizona State.json',
#  '400935286 - UCLA vs Colorado.json',
#  '400935287 - Oregon vs California.json',
#  '400935288 - Oregon State vs Washington.json',
#  '400935365 - Illinois vs Nebraska.json',
#  '400935366 - Michigan State vs Iowa.json',
#  '400935367 - Minnesota vs Maryland.json',
#  '400935368 - Penn State vs Indiana.json',
#  '400935369 - Rutgers vs Ohio State.json',
#  '400935370 - Wisconsin vs Northwestern.json',
#  '400937479 - Duke vs Miami.json',
#  '400937480 - Boston College vs Central Michigan.json',
#  '400937481 - Virginia Tech vs Clemson.json',
#  '400937482 - Wake Forest vs Florida State.json',
#  '400937483 - Georgia Tech vs North Carolina.json',
#  '400937484 - Louisville vs Murray State.json',
#  '400937485 - NC State vs Syracuse.json',
#  '400937486 - Pittsburgh vs Rice.json',
#  '400938622 - Florida Intl vs Charlotte.json',
#  '400938623 - Florida Atlantic vs Middle Tennessee.json',
#  '400938624 - Louisiana Tech vs South Alabama.json',
#  '400938625 - Cincinnati vs Marshall.json',
#  '400938626 - Southern Mississippi vs North Texas.json',
#  '400938890 - UMass vs Ohio.json',
#  '400941809 - SMU vs Connecticut.json',
#  '400941810 - East Carolina vs South Florida.json',
#  '400941811 - Temple vs Houston.json',
#  '400941813 - Tulsa vs Navy.json',
#  '400944844 - Louisiana Monroe vs Coastal Carolina.json',
#  '400944845 - Wyoming vs Texas State.json',
#  '400944904 - Bowling Green vs Akron.json',
#  '400944905 - Western Michigan vs Ball State.json',
#  '400944986 - Kent State vs Buffalo.json',
#  '400944987 - San Diego State vs Northern Illinois.json',
#  '400945262 - Utah State vs BYU.json',
#  '400945263 - New Mexico vs Air Force.json',
#  '400945264 - Hawai_i vs Colorado State.json',
#  '400945265 - Fresno State vs Nevada.json',
#  '400945266 - UNLV vs San Jose╠ü State.json',
#  '400985406 - UCF vs Memphis.json',
#  '400933880 - Auburn vs Ole Miss.json',
#  '400933881 - Kentucky vs Missouri.json',
#  '400933882 - Florida vs LSU.json',
#  '400933883 - South Carolina vs Arkansas.json',
#  '400933884 - Texas A_M vs Alabama.json',
#  '400933885 - Vanderbilt vs Georgia.json',
#  '400934522 - TCU vs West Virginia.json',
#  '400934523 - Oklahoma vs Iowa State.json',
#  '400934524 - Texas vs Kansas State.json',
#  '400934525 - Kansas vs Texas Tech.json',
#  '400934564 - Rice vs Army.json',
#  '400934577 - North Carolina vs Notre Dame.json',
#  '400935289 - Colorado vs Arizona.json',
#  '400935290 - USC vs Oregon State.json',
#  '400935291 - Utah vs Stanford.json',
#  '400935292 - Oregon vs Washington State.json',
#  '400935293 - Washington vs California.json',
#  '400935371 - Iowa vs Illinois.json',
#  '400935372 - Michigan vs Michigan State.json',
#  '400935373 - Nebraska vs Wisconsin.json',
#  '400935374 - Northwestern vs Penn State.json',
#  '400935375 - Ohio State vs Maryland.json',
#  '400935376 - Purdue vs Minnesota.json',
#  '400937487 - NC State vs Louisville.json',
#  '400937488 - Boston College vs Virginia Tech.json',
#  '400937489 - Clemson vs Wake Forest.json',
#  '400937490 - Virginia vs Duke.json',
#  '400937491 - Syracuse vs Pittsburgh.json',
#  '400938627 - Charlotte vs Marshall.json',
#  '400938628 - Middle Tennessee vs Florida Intl.json',
#  '400938629 - Old Dominion vs Florida Atlantic.json',
#  '400938630 - UAB vs Louisiana Tech.json',
#  '400938631 - UTEP vs Western Kentucky.json',
#  '400938676 - UT San Antonio vs Southern Mississippi.json',
#  '400941814 - Connecticut vs Memphis.json',
#  '400941815 - Navy vs Air Force.json',
#  '400941816 - Cincinnati vs UCF.json',
#  '400941817 - East Carolina vs Temple.json',
#  '400941818 - Houston vs SMU.json',
#  '400941819 - Tulane vs Tulsa.json',
#  '400944846 - Georgia Southern vs Arkansas State.json',
#  '400944847 - Coastal Carolina vs Georgia State.json',
#  '400944848 - Idaho vs Louisiana.json',
#  '400944849 - Texas State vs Louisiana Monroe.json',
#  '400944850 - Appalachian State vs New Mexico State.json',
#  '400944988 - Akron vs Ball State.json',
#  '400944989 - Miami (OH) vs Bowling Green.json',
#  '400944990 - Ohio vs Central Michigan.json',
#  '400944991 - Toledo vs Eastern Michigan.json',
#  '400944992 - Northern Illinois vs Kent State.json',
#  '400944993 - Buffalo vs Western Michigan.json',
#  '400945267 - BYU vs Boise State.json',
#  '400945268 - Utah State vs Colorado State.json',
#  '400945269 - San Jose╠ü State vs Fresno State.json',
#  '400945270 - Nevada vs Hawai_i.json',
#  '400945271 - UNLV vs San Diego State.json',
#  '400981507 - Florida State vs Miami.json',
#  '400982707 - Indiana vs Charleston Southern.json',
#  '400933886 - Alabama vs Arkansas.json',
#  '400933887 - Florida vs Texas A_M.json',
#  '400933888 - Georgia vs Missouri.json',
#  '400933889 - LSU vs Auburn.json',
#  '400933890 - Ole Miss vs Vanderbilt.json',
#  '400933891 - Mississippi State vs BYU.json',
#  '400933892 - Tennessee vs South Carolina.json',
#  '400934526 - Oklahoma State vs Baylor.json',
#  '400934527 - Iowa State vs Kansas.json',
#  '400934528 - Texas vs Oklahoma.json',
#  '400934529 - West Virginia vs Texas Tech.json',
#  '400934530 - Kansas State vs TCU.json',
#  '400934567 - Army vs Eastern Michigan.json',
#  '400935294 - California vs Washington State.json',
#  '400935295 - Arizona vs UCLA.json',
#  '400935296 - Arizona State vs Washington.json',
#  '400935297 - USC vs Utah.json',
#  '400935298 - Oregon State vs Colorado.json',
#  '400935299 - Stanford vs Oregon.json',
#  '400935377 - Maryland vs Northwestern.json',
#  '400935378 - Illinois vs Rutgers.json',
#  '400935379 - Indiana vs Michigan.json',
#  '400935380 - Minnesota vs Michigan State.json',
#  '400935381 - Nebraska vs Ohio State.json',
#  '400935382 - Wisconsin vs Purdue.json',
#  '400937493 - Syracuse vs Clemson.json',
#  '400937494 - Louisville vs Boston College.json',
#  '400937495 - Duke vs Florida State.json',
#  '400937496 - North Carolina vs Virginia.json',
#  '400937497 - Pittsburgh vs NC State.json',
#  '400938632 - Western Kentucky vs Charlotte.json',
#  '400938633 - Florida Intl vs Tulane.json',
#  '400938634 - Marshall vs Old Dominion.json',
#  '400938635 - UAB vs Middle Tennessee.json',
#  '400938636 - North Texas vs UT San Antonio.json',
#  '400938637 - Southern Mississippi vs UTEP.json',
#  '400941820 - UCF vs East Carolina.json',
#  '400941821 - Temple vs Connecticut.json',
#  '400941822 - Tulsa vs Houston.json',
#  '400941823 - Memphis vs Navy.json',
#  '400941832 - South Florida vs Cincinnati.json',
#  '400944851 - Troy vs South Alabama.json',
#  '400944852 - Louisiana vs Texas State.json',
#  '400944853 - Idaho vs Appalachian State.json',
#  '400944854 - Arkansas State vs Coastal Carolina.json',
#  '400944855 - Georgia Southern vs New Mexico State.json',
#  '400944856 - Louisiana Monroe vs Georgia State.json',
#  '400944994 - Western Michigan vs Akron.json',
#  '400944995 - Kent State vs Miami (OH).json',
#  '400944996 - Buffalo vs Northern Illinois.json',
#  '400944997 - Bowling Green vs Ohio.json',
#  '400944998 - Central Michigan vs Toledo.json',
#  '400945272 - Air Force vs UNLV.json',
#  '400945273 - San Diego State vs Boise State.json',
#  '400945274 - Colorado State vs Nevada.json',
#  '400945275 - Fresno State vs New Mexico.json',
#  '400945276 - Utah State vs Wyoming.json',
#  '400945277 - Hawai_i vs San Jose╠ü State.json',
#  '400981508 - Miami vs Georgia Tech.json',
#  '400933893 - Alabama vs Tennessee.json',
#  '400933894 - Arkansas vs Auburn.json',
#  '400933895 - Ole Miss vs LSU.json',
#  '400933896 - Mississippi State vs Kentucky.json',
#  '400933897 - Missouri vs Idaho.json',
#  '400934531 - Texas Tech vs Iowa State.json',
#  '400934532 - TCU vs Kansas.json',
#  '400934533 - Baylor vs West Virginia.json',
#  '400934534 - Kansas State vs Oklahoma.json',
#  '400934535 - Texas vs Oklahoma State.json',
#  '400934568 - Army vs Temple.json',
#  '400934578 - Notre Dame vs USC.json',
#  '400935300 - California vs Arizona.json',
#  '400935301 - Utah vs Arizona State.json',
#  '400935302 - UCLA vs Oregon.json',
#  '400935303 - Washington State vs Colorado.json',
#  '400935383 - Michigan State vs Indiana.json',
#  '400935384 - Minnesota vs Illinois.json',
#  '400935385 - Northwestern vs Iowa.json',
#  '400935386 - Penn State vs Michigan.json',
#  '400935387 - Rutgers vs Purdue.json',
#  '400935388 - Wisconsin vs Maryland.json',
#  '400937498 - Virginia vs Boston College.json',
#  '400937499 - Duke vs Pittsburgh.json',
#  '400937500 - Florida State vs Louisville.json',
#  '400937501 - Georgia Tech vs Wake Forest.json',
#  '400937502 - Miami vs Syracuse.json',
#  '400937503 - Virginia Tech vs North Carolina.json',
#  '400938638 - Charlotte vs UAB.json',
#  '400938639 - Florida Atlantic vs North Texas.json',
#  '400938640 - Louisiana Tech vs Southern Mississippi.json',
#  '400938641 - Old Dominion vs Western Kentucky.json',
#  '400938642 - UT San Antonio vs Rice.json',
#  '400938674 - Middle Tennessee vs Marshall.json',
#  '400938892 - UMass vs Georgia Southern.json',
#  '400941824 - Houston vs Memphis.json',
#  '400941825 - Navy vs UCF.json',
#  '400941826 - Cincinnati vs SMU.json',
#  '400941827 - Connecticut vs Tulsa.json',
#  '400941828 - East Carolina vs BYU.json',
#  '400941829 - Tulane vs South Florida.json',
#  '400944857 - Arkansas State vs Louisiana.json',
#  '400944858 - Appalachian State vs Coastal Carolina.json',
#  '400944859 - South Alabama vs Louisiana Monroe.json',
#  '400944860 - Georgia State vs Troy.json',
#  '400944999 - Toledo vs Akron.json',
#  '400945000 - Miami (OH) vs Buffalo.json',
#  '400945001 - Ball State vs Central Michigan.json',
#  '400945002 - Ohio vs Kent State.json',
#  '400945003 - Bowling Green vs Northern Illinois.json',
#  '400945004 - Eastern Michigan vs Western Michigan.json',
#  '400945278 - Nevada vs Air Force.json',
#  '400945279 - Boise State vs Wyoming.json',
#  '400945280 - New Mexico vs Colorado State.json',
#  '400945281 - UNLV vs Utah State.json',
#  '400945282 - San Diego State vs Fresno State.json',
#  '400933898 - Florida vs Georgia.json',
#  '400933899 - Kentucky vs Tennessee.json',
#  '400933900 - Ole Miss vs Arkansas.json',
#  '400933901 - Connecticut vs Missouri.json',
#  '400933902 - South Carolina vs Vanderbilt.json',
#  '400933903 - Texas A_M vs Mississippi State.json',
#  '400934536 - Kansas vs Kansas State.json',
#  '400934537 - West Virginia vs Oklahoma State.json',
#  '400934538 - Baylor vs Texas.json',
#  '400934539 - Oklahoma vs Texas Tech.json',
#  '400934540 - Iowa State vs TCU.json',
#  '400934579 - Notre Dame vs NC State.json',
#  '400935304 - Oregon State vs Stanford.json',
#  '400935305 - Arizona vs Washington State.json',
#  '400935306 - Arizona State vs USC.json',
#  '400935307 - Washington vs UCLA.json',
#  '400935308 - Colorado vs California.json',
#  '400935309 - Oregon vs Utah.json',
#  '400935389 - Northwestern vs Michigan State.json',
#  '400935390 - Illinois vs Wisconsin.json',
#  '400935391 - Iowa vs Minnesota.json',
#  '400935392 - Maryland vs Indiana.json',
#  '400935393 - Michigan vs Rutgers.json',
#  '400935394 - Ohio State vs Penn State.json',
#  '400935395 - Purdue vs Nebraska.json',
#  '400937504 - Boston College vs Florida State.json',
#  '400937505 - Clemson vs Georgia Tech.json',
#  '400937506 - Virginia Tech vs Duke.json',
#  '400937507 - Wake Forest vs Louisville.json',
#  '400937508 - North Carolina vs Miami.json',
#  '400937509 - Pittsburgh vs Virginia.json',
#  '400938643 - Marshall vs Florida Intl.json',
#  '400938644 - Western Kentucky vs Florida Atlantic.json',
#  '400938645 - Rice vs Louisiana Tech.json',
#  '400938646 - North Texas vs Old Dominion.json',
#  '400938647 - Southern Mississippi vs UAB.json',
#  '400938648 - UTEP vs UT San Antonio.json',
#  '400938893 - UMass vs Appalachian State.json',
#  '400941830 - Memphis vs Tulane.json',
#  '400941831 - SMU vs Tulsa.json',
#  '400941839 - South Florida vs Houston.json',
#  '400944861 - Georgia State vs South Alabama.json',
#  '400944862 - New Mexico State vs Arkansas State.json',
#  '400944863 - Coastal Carolina vs Texas State.json',
#  '400944864 - Troy vs Georgia Southern.json',
#  '400944865 - Idaho vs Louisiana Monroe.json',
#  '400945005 - Northern Illinois vs Eastern Michigan.json',
#  '400945006 - Ball State vs Toledo.json',
#  '400945007 - Akron vs Buffalo.json',
#  '400945283 - Colorado State vs Air Force.json',
#  '400945284 - Utah State vs Boise State.json',
#  '400945285 - Wyoming vs New Mexico.json',
#  '400945286 - Fresno State vs UNLV.json',
#  '400945287 - Hawai_i vs San Diego State.json',
#  '400945288 - BYU vs San Jose State.json',
#  '400986609 - UCF vs Austin Peay.json',
#  '.ipynb_checkpoints',
#  '.ipynb_checkpoints']

# %% [markdown]
# ### Alabama Games

# %%
#create iterable list with the default for alabama games both home and away
bama_cases = [
    '**/full/**/*- Alabama *json',
    '**/full/**/*vs Alabama.*json',
]

#create a blank list to store the file path of alabama games
bama_game_files = []

#find all alabama games and add them to a list
for case in bama_cases:
    new_files = list(cwd_path.rglob(case))
    bama_game_files.extend(new_files)

#bama_game_files = [file for file in bama_game_files if 'Bowl' not in file.parts]
#create a dictionary with week as the key and file path as the value
bama_game_files = {file.parts[2]: file for file in bama_game_files}

# %%
# Code used to remove unwanted the 3 unwanted games from the folder of all games
# Create a list to path of games I want to remove 
# invalid_game_path = ['full/Week 1/400953746 - SOUTH vs NORTH.json', 'full/Week 1/400953747 - WEST vs EAST.json', 'full/Week 1/401003756 - National vs American.json'],
# for loop to iterate through the list and remove the game from path if it 
# for game in invalid_game_path:
#     if os.path.exists(game):
#         os.remove(game)
# 
all_game_dict
# Out:
# {'400953322 - North Texas vs Troy.json': WindowsPath('full/Bowl/400953322 - North Texas vs Troy.json'),
#  '400953323 - Oregon vs Boise State.json': WindowsPath('full/Bowl/400953323 - Oregon vs Boise State.json'),
#  '400953324 - Colorado State vs Marshall.json': WindowsPath('full/Bowl/400953324 - Colorado State vs Marshall.json'),
#  '400953325 - Arkansas State vs Middle Tennessee.json': WindowsPath('full/Bowl/400953325 - Arkansas State vs Middle Tennessee.json'),
#  '400953386 - Florida Atlantic vs Akron.json': WindowsPath('full/Bowl/400953386 - Florida Atlantic vs Akron.json'),
#  '400953387 - Florida Intl vs Temple.json': WindowsPath('full/Bowl/400953387 - Florida Intl vs Temple.json'),
#  '400953388 - Ohio vs UAB.json': WindowsPath('full/Bowl/400953388 - Ohio vs UAB.json'),
#  '400953389 - Wyoming vs Central Michigan.json': WindowsPath('full/Bowl/400953389 - Wyoming vs Central Michigan.json'),
#  '400953390 - South Florida vs Texas Tech.json': WindowsPath('full/Bowl/400953390 - South Florida vs Texas Tech.json'),
#  '400953391 - Army vs San Diego State.json': WindowsPath('full/Bowl/400953391 - Army vs San Diego State.json'),
#  '400953392 - Toledo vs Appalachian State.json': WindowsPath('full/Bowl/400953392 - Toledo vs Appalachian State.json'),
#  '400953393 - Houston vs Fresno State.json': WindowsPath('full/Bowl/400953393 - Houston vs Fresno State.json'),
#  '400953394 - Northern Illinois vs Duke.json': WindowsPath('full/Bowl/400953394 - Northern Illinois vs Duke.json'),
#  '400953395 - West Virginia vs Utah.json': WindowsPath('full/Bowl/400953395 - West Virginia vs Utah.json'),
#  '400953396 - UCLA vs Kansas State.json': WindowsPath('full/Bowl/400953396 - UCLA vs Kansas State.json'),
#  '400953397 - Florida State vs Southern Mississippi.json': WindowsPath('full/Bowl/400953397 - Florida State vs Southern Mississippi.json'),
#  '400953398 - Boston College vs Iowa.json': WindowsPath('full/Bowl/400953398 - Boston College vs Iowa.json'),
#  '400953399 - Missouri vs Texas.json': WindowsPath('full/Bowl/400953399 - Missouri vs Texas.json'),
#  '400953400 - Navy vs Virginia.json': WindowsPath('full/Bowl/400953400 - Navy vs Virginia.json'),
#  '400953401 - TCU vs Stanford.json': WindowsPath('full/Bowl/400953401 - TCU vs Stanford.json'),
#  '400953402 - Texas A_M vs Wake Forest.json': WindowsPath('full/Bowl/400953402 - Texas A_M vs Wake Forest.json'),
#  '400953403 - Northwestern vs Kentucky.json': WindowsPath('full/Bowl/400953403 - Northwestern vs Kentucky.json'),
#  '400953404 - Ohio State vs USC.json': WindowsPath('full/Bowl/400953404 - Ohio State vs USC.json'),
#  '400953405 - Mississippi State vs Louisville.json': WindowsPath('full/Bowl/400953405 - Mississippi State vs Louisville.json'),
#  '400953406 - Memphis vs Iowa State.json': WindowsPath('full/Bowl/400953406 - Memphis vs Iowa State.json'),
#  '400953407 - Penn State vs Washington.json': WindowsPath('full/Bowl/400953407 - Penn State vs Washington.json'),
#  '400953408 - Miami vs Wisconsin.json': WindowsPath('full/Bowl/400953408 - Miami vs Wisconsin.json'),
#  '400953409 - Georgia State vs Western Kentucky.json': WindowsPath('full/Bowl/400953409 - Georgia State vs Western Kentucky.json'),
#  '400953410 - South Carolina vs Michigan.json': WindowsPath('full/Bowl/400953410 - South Carolina vs Michigan.json'),
#  '400953411 - Auburn vs UCF.json': WindowsPath('full/Bowl/400953411 - Auburn vs UCF.json'),
#  '400953412 - Oklahoma vs Georgia.json': WindowsPath('full/Bowl/400953412 - Oklahoma vs Georgia.json'),
#  '400953413 - Clemson vs Alabama.json': WindowsPath('full/Bowl/400953413 - Clemson vs Alabama.json'),
#  '400953414 - LSU vs Notre Dame.json': WindowsPath('full/Bowl/400953414 - LSU vs Notre Dame.json'),
#  '400953415 - Georgia vs Alabama.json': WindowsPath('full/Bowl/400953415 - Georgia vs Alabama.json'),
#  '400953416 - Oklahoma State vs Virginia Tech.json': WindowsPath('full/Bowl/400953416 - Oklahoma State vs Virginia Tech.json'),
#  '400953417 - Arizona State vs NC State.json': WindowsPath('full/Bowl/400953417 - Arizona State vs NC State.json'),
#  '400954523 - SMU vs Louisiana Tech.json': WindowsPath('full/Bowl/400954523 - SMU vs Louisiana Tech.json'),
#  '400959397 - Michigan State vs Washington State.json': WindowsPath('full/Bowl/400959397 - Michigan State vs Washington State.json'),
#  '400959398 - Purdue vs Arizona.json': WindowsPath('full/Bowl/400959398 - Purdue vs Arizona.json'),
#  '400966332 - Utah State vs New Mexico State.json': WindowsPath('full/Bowl/400966332 - Utah State vs New Mexico State.json'),
#  '400933827 - Alabama vs Florida State.json': WindowsPath('full/Week 1/400933827 - Alabama vs Florida State.json'),
#  '400933828 - Arkansas vs Florida A_M.json': WindowsPath('full/Week 1/400933828 - Arkansas vs Florida A_M.json'),
#  '400933829 - Auburn vs Georgia Southern.json': WindowsPath('full/Week 1/400933829 - Auburn vs Georgia Southern.json'),
#  '400933830 - Florida vs Michigan.json': WindowsPath('full/Week 1/400933830 - Florida vs Michigan.json'),
#  '400933831 - Georgia vs Appalachian State.json': WindowsPath('full/Week 1/400933831 - Georgia vs Appalachian State.json'),
#  '400933832 - Southern Mississippi vs Kentucky.json': WindowsPath('full/Week 1/400933832 - Southern Mississippi vs Kentucky.json'),
#  '400933833 - LSU vs BYU.json': WindowsPath('full/Week 1/400933833 - LSU vs BYU.json'),
#  '400933834 - Ole Miss vs South Alabama.json': WindowsPath('full/Week 1/400933834 - Ole Miss vs South Alabama.json'),
#  '400933835 - Mississippi State vs Charleston Southern.json': WindowsPath('full/Week 1/400933835 - Mississippi State vs Charleston Southern.json'),
#  '400933836 - Missouri vs Missouri State.json': WindowsPath('full/Week 1/400933836 - Missouri vs Missouri State.json'),
#  '400933837 - South Carolina vs NC State.json': WindowsPath('full/Week 1/400933837 - South Carolina vs NC State.json'),
#  '400933838 - UCLA vs Texas A_M.json': WindowsPath('full/Week 1/400933838 - UCLA vs Texas A_M.json'),
#  '400933839 - Middle Tennessee vs Vanderbilt.json': WindowsPath('full/Week 1/400933839 - Middle Tennessee vs Vanderbilt.json'),
#  '400933840 - Georgia Tech vs Tennessee.json': WindowsPath('full/Week 1/400933840 - Georgia Tech vs Tennessee.json'),
#  '400934488 - Iowa State vs Northern Iowa.json': WindowsPath('full/Week 1/400934488 - Iowa State vs Northern Iowa.json'),
#  '400934489 - Baylor vs Liberty.json': WindowsPath('full/Week 1/400934489 - Baylor vs Liberty.json'),
#  '400934490 - Kansas vs Southeast Missouri State.json': WindowsPath('full/Week 1/400934490 - Kansas vs Southeast Missouri State.json'),
#  '400934491 - Kansas State vs Central Arkansas.json': WindowsPath('full/Week 1/400934491 - Kansas State vs Central Arkansas.json'),
#  '400934492 - Oklahoma vs UTEP.json': WindowsPath('full/Week 1/400934492 - Oklahoma vs UTEP.json'),
#  '400934493 - Oklahoma State vs Tulsa.json': WindowsPath('full/Week 1/400934493 - Oklahoma State vs Tulsa.json'),
#  '400934494 - TCU vs Jackson State.json': WindowsPath('full/Week 1/400934494 - TCU vs Jackson State.json'),
#  '400934495 - Texas vs Maryland.json': WindowsPath('full/Week 1/400934495 - Texas vs Maryland.json'),
#  '400934496 - Texas Tech vs Eastern Washington.json': WindowsPath('full/Week 1/400934496 - Texas Tech vs Eastern Washington.json'),
#  '400934497 - Virginia Tech vs West Virginia.json': WindowsPath('full/Week 1/400934497 - Virginia Tech vs West Virginia.json'),
#  '400934570 - Army vs Fordham.json': WindowsPath('full/Week 1/400934570 - Army vs Fordham.json'),
#  '400934573 - Notre Dame vs Temple.json': WindowsPath('full/Week 1/400934573 - Notre Dame vs Temple.json'),
#  '400935229 - Indiana vs Ohio State.json': WindowsPath('full/Week 1/400935229 - Indiana vs Ohio State.json'),
#  '400935230 - Minnesota vs Buffalo.json': WindowsPath('full/Week 1/400935230 - Minnesota vs Buffalo.json'),
#  '400935231 - Wisconsin vs Utah State.json': WindowsPath('full/Week 1/400935231 - Wisconsin vs Utah State.json'),
#  '400935232 - Illinois vs Ball State.json': WindowsPath('full/Week 1/400935232 - Illinois vs Ball State.json'),
#  '400935233 - Iowa vs Wyoming.json': WindowsPath('full/Week 1/400935233 - Iowa vs Wyoming.json'),
#  '400935234 - Michigan State vs Bowling Green.json': WindowsPath('full/Week 1/400935234 - Michigan State vs Bowling Green.json'),
#  '400935235 - Nebraska vs Arkansas State.json': WindowsPath('full/Week 1/400935235 - Nebraska vs Arkansas State.json'),
#  '400935236 - Northwestern vs Nevada.json': WindowsPath('full/Week 1/400935236 - Northwestern vs Nevada.json'),
#  '400935237 - Penn State vs Akron.json': WindowsPath('full/Week 1/400935237 - Penn State vs Akron.json'),
#  '400935238 - Purdue vs Louisville.json': WindowsPath('full/Week 1/400935238 - Purdue vs Louisville.json'),
#  '400935247 - Arizona State vs New Mexico State.json': WindowsPath('full/Week 1/400935247 - Arizona State vs New Mexico State.json'),
#  '400935248 - Utah vs North Dakota.json': WindowsPath('full/Week 1/400935248 - Utah vs North Dakota.json'),
#  '400935249 - Colorado vs Colorado State.json': WindowsPath('full/Week 1/400935249 - Colorado vs Colorado State.json'),
#  '400935250 - Rutgers vs Washington.json': WindowsPath('full/Week 1/400935250 - Rutgers vs Washington.json'),
#  '400935251 - Arizona vs Northern Arizona.json': WindowsPath('full/Week 1/400935251 - Arizona vs Northern Arizona.json'),
#  '400935252 - USC vs Western Michigan.json': WindowsPath('full/Week 1/400935252 - USC vs Western Michigan.json'),
#  '400935253 - Oregon vs Southern Utah.json': WindowsPath('full/Week 1/400935253 - Oregon vs Southern Utah.json'),
#  '400935254 - Oregon State vs Portland State.json': WindowsPath('full/Week 1/400935254 - Oregon State vs Portland State.json'),
#  '400935255 - Washington State vs Montana State.json': WindowsPath('full/Week 1/400935255 - Washington State vs Montana State.json'),
#  '400935256 - North Carolina vs California.json': WindowsPath('full/Week 1/400935256 - North Carolina vs California.json'),
#  '400935257 - Rice vs Stanford.json': WindowsPath('full/Week 1/400935257 - Rice vs Stanford.json'),
#  '400935282 - Colorado State vs Oregon State.json': WindowsPath('full/Week 1/400935282 - Colorado State vs Oregon State.json'),
#  '400937445 - Wake Forest vs Presbyterian College.json': WindowsPath('full/Week 1/400937445 - Wake Forest vs Presbyterian College.json'),
#  '400937446 - Northern Illinois vs Boston College.json': WindowsPath('full/Week 1/400937446 - Northern Illinois vs Boston College.json'),
#  '400937447 - Clemson vs Kent State.json': WindowsPath('full/Week 1/400937447 - Clemson vs Kent State.json'),
#  '400937448 - Duke vs North Carolina Central.json': WindowsPath('full/Week 1/400937448 - Duke vs North Carolina Central.json'),
#  '400937449 - Miami vs Bethune-Cookman.json': WindowsPath('full/Week 1/400937449 - Miami vs Bethune-Cookman.json'),
#  '400937450 - Pittsburgh vs Youngstown State.json': WindowsPath('full/Week 1/400937450 - Pittsburgh vs Youngstown State.json'),
#  '400937451 - Syracuse vs Central Connecticut.json': WindowsPath('full/Week 1/400937451 - Syracuse vs Central Connecticut.json'),
#  '400937452 - Virginia vs William _ Mary.json': WindowsPath('full/Week 1/400937452 - Virginia vs William _ Mary.json'),
#  '400938591 - UCF vs Florida Intl.json': WindowsPath('full/Week 1/400938591 - UCF vs Florida Intl.json'),
#  '400938592 - Florida Atlantic vs Navy.json': WindowsPath('full/Week 1/400938592 - Florida Atlantic vs Navy.json'),
#  '400938593 - Louisiana Tech vs Northwestern State.json': WindowsPath('full/Week 1/400938593 - Louisiana Tech vs Northwestern State.json'),
#  '400938594 - Marshall vs Miami (OH).json': WindowsPath('full/Week 1/400938594 - Marshall vs Miami (OH).json'),
#  '400938595 - North Texas vs Lamar.json': WindowsPath('full/Week 1/400938595 - North Texas vs Lamar.json'),
#  '400938596 - Old Dominion vs Albany.json': WindowsPath('full/Week 1/400938596 - Old Dominion vs Albany.json'),
#  '400938597 - UAB vs Alabama A_M.json': WindowsPath('full/Week 1/400938597 - UAB vs Alabama A_M.json'),
#  '400938599 - Western Kentucky vs Eastern Kentucky.json': WindowsPath('full/Week 1/400938599 - Western Kentucky vs Eastern Kentucky.json'),
#  '400938887 - UMass vs Hawai_i.json': WindowsPath('full/Week 1/400938887 - UMass vs Hawai_i.json'),
#  '400938888 - Coastal Carolina vs UMass.json': WindowsPath('full/Week 1/400938888 - Coastal Carolina vs UMass.json'),
#  '400941786 - San Jose╠ü State vs South Florida.json': WindowsPath('full/Week 1/400941786 - San Jose╠ü State vs South Florida.json'),
#  '400941787 - Cincinnati vs Austin Peay.json': WindowsPath('full/Week 1/400941787 - Cincinnati vs Austin Peay.json'),
#  '400941788 - Connecticut vs Holy Cross.json': WindowsPath('full/Week 1/400941788 - Connecticut vs Holy Cross.json'),
#  '400941789 - Memphis vs Louisiana Monroe.json': WindowsPath('full/Week 1/400941789 - Memphis vs Louisiana Monroe.json'),
#  '400941790 - East Carolina vs James Madison.json': WindowsPath('full/Week 1/400941790 - East Carolina vs James Madison.json'),
#  '400941791 - South Florida vs Stony Brook.json': WindowsPath('full/Week 1/400941791 - South Florida vs Stony Brook.json'),
#  '400941792 - SMU vs Stephen F. Austin.json': WindowsPath('full/Week 1/400941792 - SMU vs Stephen F. Austin.json'),
#  '400941793 - Tulane vs Grambling.json': WindowsPath('full/Week 1/400941793 - Tulane vs Grambling.json'),
#  '400944826 - Georgia State vs Tennessee State.json': WindowsPath('full/Week 1/400944826 - Georgia State vs Tennessee State.json'),
#  '400944827 - Idaho vs Sacramento State.json': WindowsPath('full/Week 1/400944827 - Idaho vs Sacramento State.json'),
#  '400944829 - Texas State vs Houston Baptist.json': WindowsPath('full/Week 1/400944829 - Texas State vs Houston Baptist.json'),
#  '400944830 - Boise State vs Troy.json': WindowsPath('full/Week 1/400944830 - Boise State vs Troy.json'),
#  '400944889 - Toledo vs Elon.json': WindowsPath('full/Week 1/400944889 - Toledo vs Elon.json'),
#  '400944890 - Central Michigan vs Rhode Island.json': WindowsPath('full/Week 1/400944890 - Central Michigan vs Rhode Island.json'),
#  '400944891 - Eastern Michigan vs Charlotte.json': WindowsPath('full/Week 1/400944891 - Eastern Michigan vs Charlotte.json'),
#  '400944892 - Ohio vs Hampton.json': WindowsPath('full/Week 1/400944892 - Ohio vs Hampton.json'),
#  '400945031 - BYU vs Portland State.json': WindowsPath('full/Week 1/400945031 - BYU vs Portland State.json'),
#  '400945246 - Air Force vs VMI.json': WindowsPath('full/Week 1/400945246 - Air Force vs VMI.json'),
#  '400945247 - New Mexico vs Abilene Christian.json': WindowsPath('full/Week 1/400945247 - New Mexico vs Abilene Christian.json'),
#  '400945248 - Fresno State vs Incarnate Word.json': WindowsPath('full/Week 1/400945248 - Fresno State vs Incarnate Word.json'),
#  '400945249 - Hawai_i vs Western Carolina.json': WindowsPath('full/Week 1/400945249 - Hawai_i vs Western Carolina.json'),
#  '400945250 - San Diego State vs UC Davis.json': WindowsPath('full/Week 1/400945250 - San Diego State vs UC Davis.json'),
#  '400945251 - San Jose╠ü State vs Cal Poly.json': WindowsPath('full/Week 1/400945251 - San Jose╠ü State vs Cal Poly.json'),
#  '400945252 - UNLV vs Howard.json': WindowsPath('full/Week 1/400945252 - UNLV vs Howard.json'),
#  '400933904 - Alabama vs LSU.json': WindowsPath('full/Week 10/400933904 - Alabama vs LSU.json'),
#  '400933905 - Arkansas vs Coastal Carolina.json': WindowsPath('full/Week 10/400933905 - Arkansas vs Coastal Carolina.json'),
#  '400933906 - Georgia vs South Carolina.json': WindowsPath('full/Week 10/400933906 - Georgia vs South Carolina.json'),
#  '400933907 - Kentucky vs Ole Miss.json': WindowsPath('full/Week 10/400933907 - Kentucky vs Ole Miss.json'),
#  '400933908 - Mississippi State vs UMass.json': WindowsPath('full/Week 10/400933908 - Mississippi State vs UMass.json'),
#  '400933909 - Missouri vs Florida.json': WindowsPath('full/Week 10/400933909 - Missouri vs Florida.json'),
#  '400933910 - Tennessee vs Southern Mississippi.json': WindowsPath('full/Week 10/400933910 - Tennessee vs Southern Mississippi.json'),
#  '400933911 - Texas A_M vs Auburn.json': WindowsPath('full/Week 10/400933911 - Texas A_M vs Auburn.json'),
#  '400933912 - Vanderbilt vs Western Kentucky.json': WindowsPath('full/Week 10/400933912 - Vanderbilt vs Western Kentucky.json'),
#  '400934541 - Kansas vs Baylor.json': WindowsPath('full/Week 10/400934541 - Kansas vs Baylor.json'),
#  '400934542 - West Virginia vs Iowa State.json': WindowsPath('full/Week 10/400934542 - West Virginia vs Iowa State.json'),
#  '400934543 - Texas Tech vs Kansas State.json': WindowsPath('full/Week 10/400934543 - Texas Tech vs Kansas State.json'),
#  '400934544 - Oklahoma State vs Oklahoma.json': WindowsPath('full/Week 10/400934544 - Oklahoma State vs Oklahoma.json'),
#  '400934545 - TCU vs Texas.json': WindowsPath('full/Week 10/400934545 - TCU vs Texas.json'),
#  '400934569 - Air Force vs Army.json': WindowsPath('full/Week 10/400934569 - Air Force vs Army.json'),
#  '400934580 - Notre Dame vs Wake Forest.json': WindowsPath('full/Week 10/400934580 - Notre Dame vs Wake Forest.json'),
#  '400935310 - Utah vs UCLA.json': WindowsPath('full/Week 10/400935310 - Utah vs UCLA.json'),
#  '400935311 - USC vs Arizona.json': WindowsPath('full/Week 10/400935311 - USC vs Arizona.json'),
#  '400935312 - Arizona State vs Colorado.json': WindowsPath('full/Week 10/400935312 - Arizona State vs Colorado.json'),
#  '400935313 - Washington vs Oregon.json': WindowsPath('full/Week 10/400935313 - Washington vs Oregon.json'),
#  '400935314 - California vs Oregon State.json': WindowsPath('full/Week 10/400935314 - California vs Oregon State.json'),
#  '400935315 - Washington State vs Stanford.json': WindowsPath('full/Week 10/400935315 - Washington State vs Stanford.json'),
#  '400935396 - Indiana vs Wisconsin.json': WindowsPath('full/Week 10/400935396 - Indiana vs Wisconsin.json'),
#  '400935397 - Iowa vs Ohio State.json': WindowsPath('full/Week 10/400935397 - Iowa vs Ohio State.json'),
#  '400935398 - Michigan vs Minnesota.json': WindowsPath('full/Week 10/400935398 - Michigan vs Minnesota.json'),
#  '400935399 - Michigan State vs Penn State.json': WindowsPath('full/Week 10/400935399 - Michigan State vs Penn State.json'),
#  '400935400 - Nebraska vs Northwestern.json': WindowsPath('full/Week 10/400935400 - Nebraska vs Northwestern.json'),
#  '400935401 - Purdue vs Illinois.json': WindowsPath('full/Week 10/400935401 - Purdue vs Illinois.json'),
#  '400935402 - Rutgers vs Maryland.json': WindowsPath('full/Week 10/400935402 - Rutgers vs Maryland.json'),
#  '400937510 - NC State vs Clemson.json': WindowsPath('full/Week 10/400937510 - NC State vs Clemson.json'),
#  '400937511 - Florida State vs Syracuse.json': WindowsPath('full/Week 10/400937511 - Florida State vs Syracuse.json'),
#  '400937512 - Virginia vs Georgia Tech.json': WindowsPath('full/Week 10/400937512 - Virginia vs Georgia Tech.json'),
#  '400937513 - Miami vs Virginia Tech.json': WindowsPath('full/Week 10/400937513 - Miami vs Virginia Tech.json'),
#  '400938649 - Old Dominion vs Charlotte.json': WindowsPath('full/Week 10/400938649 - Old Dominion vs Charlotte.json'),
#  '400938650 - Florida Intl vs UT San Antonio.json': WindowsPath('full/Week 10/400938650 - Florida Intl vs UT San Antonio.json'),
#  '400938651 - Louisiana Tech vs North Texas.json': WindowsPath('full/Week 10/400938651 - Louisiana Tech vs North Texas.json'),
#  '400938652 - Middle Tennessee vs UTEP.json': WindowsPath('full/Week 10/400938652 - Middle Tennessee vs UTEP.json'),
#  '400938653 - UAB vs Rice.json': WindowsPath('full/Week 10/400938653 - UAB vs Rice.json'),
#  '400938675 - Florida Atlantic vs Marshall.json': WindowsPath('full/Week 10/400938675 - Florida Atlantic vs Marshall.json'),
#  '400941833 - Houston vs East Carolina.json': WindowsPath('full/Week 10/400941833 - Houston vs East Carolina.json'),
#  '400941834 - Temple vs Navy.json': WindowsPath('full/Week 10/400941834 - Temple vs Navy.json'),
#  '400941835 - Tulsa vs Memphis.json': WindowsPath('full/Week 10/400941835 - Tulsa vs Memphis.json'),
#  '400941836 - SMU vs UCF.json': WindowsPath('full/Week 10/400941836 - SMU vs UCF.json'),
#  '400941837 - Tulane vs Cincinnati.json': WindowsPath('full/Week 10/400941837 - Tulane vs Cincinnati.json'),
#  '400944866 - Troy vs Idaho.json': WindowsPath('full/Week 10/400944866 - Troy vs Idaho.json'),
#  '400944867 - Louisiana Monroe vs Appalachian State.json': WindowsPath('full/Week 10/400944867 - Louisiana Monroe vs Appalachian State.json'),
#  '400944868 - Georgia Southern vs Georgia State.json': WindowsPath('full/Week 10/400944868 - Georgia Southern vs Georgia State.json'),
#  '400944869 - South Alabama vs Louisiana.json': WindowsPath('full/Week 10/400944869 - South Alabama vs Louisiana.json'),
#  '400944870 - Texas State vs New Mexico State.json': WindowsPath('full/Week 10/400944870 - Texas State vs New Mexico State.json'),
#  '400945008 - Kent State vs Bowling Green.json': WindowsPath('full/Week 10/400945008 - Kent State vs Bowling Green.json'),
#  '400945009 - Ohio vs Miami (OH).json': WindowsPath('full/Week 10/400945009 - Ohio vs Miami (OH).json'),
#  '400945010 - Western Michigan vs Central Michigan.json': WindowsPath('full/Week 10/400945010 - Western Michigan vs Central Michigan.json'),
#  '400945011 - Eastern Michigan vs Ball State.json': WindowsPath('full/Week 10/400945011 - Eastern Michigan vs Ball State.json'),
#  '400945012 - Toledo vs Northern Illinois.json': WindowsPath('full/Week 10/400945012 - Toledo vs Northern Illinois.json'),
#  '400945289 - Boise State vs Nevada.json': WindowsPath('full/Week 10/400945289 - Boise State vs Nevada.json'),
#  '400945290 - Wyoming vs Colorado State.json': WindowsPath('full/Week 10/400945290 - Wyoming vs Colorado State.json'),
#  '400945291 - New Mexico vs Utah State.json': WindowsPath('full/Week 10/400945291 - New Mexico vs Utah State.json'),
#  '400945292 - Fresno State vs BYU.json': WindowsPath('full/Week 10/400945292 - Fresno State vs BYU.json'),
#  '400945293 - UNLV vs Hawai_i.json': WindowsPath('full/Week 10/400945293 - UNLV vs Hawai_i.json'),
#  '400945294 - San Jose State vs San Diego State.json': WindowsPath('full/Week 10/400945294 - San Jose State vs San Diego State.json'),
#  '400985386 - Connecticut vs South Florida.json': WindowsPath('full/Week 10/400985386 - Connecticut vs South Florida.json'),
#  '400933913 - Auburn vs Georgia.json': WindowsPath('full/Week 11/400933913 - Auburn vs Georgia.json'),
#  '400933914 - LSU vs Arkansas.json': WindowsPath('full/Week 11/400933914 - LSU vs Arkansas.json'),
#  '400933915 - Ole Miss vs Louisiana.json': WindowsPath('full/Week 11/400933915 - Ole Miss vs Louisiana.json'),
#  '400933916 - Mississippi State vs Alabama.json': WindowsPath('full/Week 11/400933916 - Mississippi State vs Alabama.json'),
#  '400933917 - Missouri vs Tennessee.json': WindowsPath('full/Week 11/400933917 - Missouri vs Tennessee.json'),
#  '400933918 - South Carolina vs Florida.json': WindowsPath('full/Week 11/400933918 - South Carolina vs Florida.json'),
#  '400933919 - Texas A_M vs New Mexico.json': WindowsPath('full/Week 11/400933919 - Texas A_M vs New Mexico.json'),
#  '400933920 - Vanderbilt vs Kentucky.json': WindowsPath('full/Week 11/400933920 - Vanderbilt vs Kentucky.json'),
#  '400934546 - Texas vs Kansas.json': WindowsPath('full/Week 11/400934546 - Texas vs Kansas.json'),
#  '400934547 - Kansas State vs West Virginia.json': WindowsPath('full/Week 11/400934547 - Kansas State vs West Virginia.json'),
#  '400934548 - Iowa State vs Oklahoma State.json': WindowsPath('full/Week 11/400934548 - Iowa State vs Oklahoma State.json'),
#  '400934549 - Baylor vs Texas Tech.json': WindowsPath('full/Week 11/400934549 - Baylor vs Texas Tech.json'),
#  '400934550 - Oklahoma vs TCU.json': WindowsPath('full/Week 11/400934550 - Oklahoma vs TCU.json'),
#  '400934565 - Army vs Duke.json': WindowsPath('full/Week 11/400934565 - Army vs Duke.json'),
#  '400934581 - Miami vs Notre Dame.json': WindowsPath('full/Week 11/400934581 - Miami vs Notre Dame.json'),
#  '400935316 - Stanford vs Washington.json': WindowsPath('full/Week 11/400935316 - Stanford vs Washington.json'),
#  '400935317 - Arizona vs Oregon State.json': WindowsPath('full/Week 11/400935317 - Arizona vs Oregon State.json'),
#  '400935318 - UCLA vs Arizona State.json': WindowsPath('full/Week 11/400935318 - UCLA vs Arizona State.json'),
#  '400935319 - Colorado vs USC.json': WindowsPath('full/Week 11/400935319 - Colorado vs USC.json'),
#  '400935320 - Utah vs Washington State.json': WindowsPath('full/Week 11/400935320 - Utah vs Washington State.json'),
#  '400935403 - Illinois vs Indiana.json': WindowsPath('full/Week 11/400935403 - Illinois vs Indiana.json'),
#  '400935404 - Maryland vs Michigan.json': WindowsPath('full/Week 11/400935404 - Maryland vs Michigan.json'),
#  '400935405 - Minnesota vs Nebraska.json': WindowsPath('full/Week 11/400935405 - Minnesota vs Nebraska.json'),
#  '400935406 - Northwestern vs Purdue.json': WindowsPath('full/Week 11/400935406 - Northwestern vs Purdue.json'),
#  '400935407 - Ohio State vs Michigan State.json': WindowsPath('full/Week 11/400935407 - Ohio State vs Michigan State.json'),
#  '400935408 - Penn State vs Rutgers.json': WindowsPath('full/Week 11/400935408 - Penn State vs Rutgers.json'),
#  '400935409 - Wisconsin vs Iowa.json': WindowsPath('full/Week 11/400935409 - Wisconsin vs Iowa.json'),
#  '400937514 - Pittsburgh vs North Carolina.json': WindowsPath('full/Week 11/400937514 - Pittsburgh vs North Carolina.json'),
#  '400937515 - Boston College vs NC State.json': WindowsPath('full/Week 11/400937515 - Boston College vs NC State.json'),
#  '400937516 - Clemson vs Florida State.json': WindowsPath('full/Week 11/400937516 - Clemson vs Florida State.json'),
#  '400937517 - Georgia Tech vs Virginia Tech.json': WindowsPath('full/Week 11/400937517 - Georgia Tech vs Virginia Tech.json'),
#  '400937518 - Louisville vs Virginia.json': WindowsPath('full/Week 11/400937518 - Louisville vs Virginia.json'),
#  '400937519 - Syracuse vs Wake Forest.json': WindowsPath('full/Week 11/400937519 - Syracuse vs Wake Forest.json'),
#  '400938654 - Charlotte vs Middle Tennessee.json': WindowsPath('full/Week 11/400938654 - Charlotte vs Middle Tennessee.json'),
#  '400938655 - Florida Intl vs Old Dominion.json': WindowsPath('full/Week 11/400938655 - Florida Intl vs Old Dominion.json'),
#  '400938656 - Louisiana Tech vs Florida Atlantic.json': WindowsPath('full/Week 11/400938656 - Louisiana Tech vs Florida Atlantic.json'),
#  '400938657 - Marshall vs Western Kentucky.json': WindowsPath('full/Week 11/400938657 - Marshall vs Western Kentucky.json'),
#  '400938658 - North Texas vs UTEP.json': WindowsPath('full/Week 11/400938658 - North Texas vs UTEP.json'),
#  '400938659 - Rice vs Southern Mississippi.json': WindowsPath('full/Week 11/400938659 - Rice vs Southern Mississippi.json'),
#  '400938660 - UT San Antonio vs UAB.json': WindowsPath('full/Week 11/400938660 - UT San Antonio vs UAB.json'),
#  '400938894 - UMass vs Maine.json': WindowsPath('full/Week 11/400938894 - UMass vs Maine.json'),
#  '400941840 - Cincinnati vs Temple.json': WindowsPath('full/Week 11/400941840 - Cincinnati vs Temple.json'),
#  '400941841 - Navy vs SMU.json': WindowsPath('full/Week 11/400941841 - Navy vs SMU.json'),
#  '400941842 - UCF vs Connecticut.json': WindowsPath('full/Week 11/400941842 - UCF vs Connecticut.json'),
#  '400941843 - East Carolina vs Tulane.json': WindowsPath('full/Week 11/400941843 - East Carolina vs Tulane.json'),
#  '400944871 - Appalachian State vs Georgia Southern.json': WindowsPath('full/Week 11/400944871 - Appalachian State vs Georgia Southern.json'),
#  '400944872 - South Alabama vs Arkansas State.json': WindowsPath('full/Week 11/400944872 - South Alabama vs Arkansas State.json'),
#  '400944873 - Texas State vs Georgia State.json': WindowsPath('full/Week 11/400944873 - Texas State vs Georgia State.json'),
#  '400944874 - Coastal Carolina vs Troy.json': WindowsPath('full/Week 11/400944874 - Coastal Carolina vs Troy.json'),
#  '400945013 - Miami (OH) vs Akron.json': WindowsPath('full/Week 11/400945013 - Miami (OH) vs Akron.json'),
#  '400945014 - Buffalo vs Bowling Green.json': WindowsPath('full/Week 11/400945014 - Buffalo vs Bowling Green.json'),
#  '400945015 - Central Michigan vs Eastern Michigan.json': WindowsPath('full/Week 11/400945015 - Central Michigan vs Eastern Michigan.json'),
#  '400945016 - Western Michigan vs Kent State.json': WindowsPath('full/Week 11/400945016 - Western Michigan vs Kent State.json'),
#  '400945017 - Ohio vs Toledo.json': WindowsPath('full/Week 11/400945017 - Ohio vs Toledo.json'),
#  '400945018 - Northern Illinois vs Ball State.json': WindowsPath('full/Week 11/400945018 - Northern Illinois vs Ball State.json'),
#  '400945295 - Air Force vs Wyoming.json': WindowsPath('full/Week 11/400945295 - Air Force vs Wyoming.json'),
#  '400945296 - Colorado State vs Boise State.json': WindowsPath('full/Week 11/400945296 - Colorado State vs Boise State.json'),
#  '400945297 - Hawai_i vs Fresno State.json': WindowsPath('full/Week 11/400945297 - Hawai_i vs Fresno State.json'),
#  '400945298 - Nevada vs San Jose State.json': WindowsPath('full/Week 11/400945298 - Nevada vs San Jose State.json'),
#  '400945299 - UNLV vs BYU.json': WindowsPath('full/Week 11/400945299 - UNLV vs BYU.json'),
#  '400933921 - Alabama vs Mercer.json': WindowsPath('full/Week 12/400933921 - Alabama vs Mercer.json'),
#  '400933922 - Arkansas vs Mississippi State.json': WindowsPath('full/Week 12/400933922 - Arkansas vs Mississippi State.json'),
#  '400933923 - Auburn vs Louisiana Monroe.json': WindowsPath('full/Week 12/400933923 - Auburn vs Louisiana Monroe.json'),
#  '400933924 - Florida vs UAB.json': WindowsPath('full/Week 12/400933924 - Florida vs UAB.json'),
#  '400933925 - Georgia vs Kentucky.json': WindowsPath('full/Week 12/400933925 - Georgia vs Kentucky.json'),
#  '400933926 - Ole Miss vs Texas A_M.json': WindowsPath('full/Week 12/400933926 - Ole Miss vs Texas A_M.json'),
#  '400933927 - South Carolina vs Wofford.json': WindowsPath('full/Week 12/400933927 - South Carolina vs Wofford.json'),
#  '400933928 - Tennessee vs LSU.json': WindowsPath('full/Week 12/400933928 - Tennessee vs LSU.json'),
#  '400933929 - Vanderbilt vs Missouri.json': WindowsPath('full/Week 12/400933929 - Vanderbilt vs Missouri.json'),
#  '400934551 - Baylor vs Iowa State.json': WindowsPath('full/Week 12/400934551 - Baylor vs Iowa State.json'),
#  '400934552 - Oklahoma State vs Kansas State.json': WindowsPath('full/Week 12/400934552 - Oklahoma State vs Kansas State.json'),
#  '400934553 - Kansas vs Oklahoma.json': WindowsPath('full/Week 12/400934553 - Kansas vs Oklahoma.json'),
#  '400934554 - West Virginia vs Texas.json': WindowsPath('full/Week 12/400934554 - West Virginia vs Texas.json'),
#  '400934555 - Texas Tech vs TCU.json': WindowsPath('full/Week 12/400934555 - Texas Tech vs TCU.json'),
#  '400934571 - North Texas vs Army.json': WindowsPath('full/Week 12/400934571 - North Texas vs Army.json'),
#  '400934582 - Notre Dame vs Navy.json': WindowsPath('full/Week 12/400934582 - Notre Dame vs Navy.json'),
#  '400935321 - Oregon vs Arizona.json': WindowsPath('full/Week 12/400935321 - Oregon vs Arizona.json'),
#  '400935322 - Oregon State vs Arizona State.json': WindowsPath('full/Week 12/400935322 - Oregon State vs Arizona State.json'),
#  '400935323 - USC vs UCLA.json': WindowsPath('full/Week 12/400935323 - USC vs UCLA.json'),
#  '400935324 - Washington vs Utah.json': WindowsPath('full/Week 12/400935324 - Washington vs Utah.json'),
#  '400935325 - Stanford vs California.json': WindowsPath('full/Week 12/400935325 - Stanford vs California.json'),
#  '400935410 - Indiana vs Rutgers.json': WindowsPath('full/Week 12/400935410 - Indiana vs Rutgers.json'),
#  '400935411 - Iowa vs Purdue.json': WindowsPath('full/Week 12/400935411 - Iowa vs Purdue.json'),
#  '400935412 - Michigan State vs Maryland.json': WindowsPath('full/Week 12/400935412 - Michigan State vs Maryland.json'),
#  '400935413 - Northwestern vs Minnesota.json': WindowsPath('full/Week 12/400935413 - Northwestern vs Minnesota.json'),
#  '400935414 - Ohio State vs Illinois.json': WindowsPath('full/Week 12/400935414 - Ohio State vs Illinois.json'),
#  '400935415 - Penn State vs Nebraska.json': WindowsPath('full/Week 12/400935415 - Penn State vs Nebraska.json'),
#  '400935416 - Wisconsin vs Michigan.json': WindowsPath('full/Week 12/400935416 - Wisconsin vs Michigan.json'),
#  '400937520 - Connecticut vs Boston College.json': WindowsPath('full/Week 12/400937520 - Connecticut vs Boston College.json'),
#  '400937521 - Clemson vs The Citadel.json': WindowsPath('full/Week 12/400937521 - Clemson vs The Citadel.json'),
#  '400937522 - Duke vs Georgia Tech.json': WindowsPath('full/Week 12/400937522 - Duke vs Georgia Tech.json'),
#  '400937523 - Florida State vs Delaware State.json': WindowsPath('full/Week 12/400937523 - Florida State vs Delaware State.json'),
#  '400937524 - Louisville vs Syracuse.json': WindowsPath('full/Week 12/400937524 - Louisville vs Syracuse.json'),
#  '400937525 - Miami vs Virginia.json': WindowsPath('full/Week 12/400937525 - Miami vs Virginia.json'),
#  '400937526 - North Carolina vs Western Carolina.json': WindowsPath('full/Week 12/400937526 - North Carolina vs Western Carolina.json'),
#  '400937527 - Wake Forest vs NC State.json': WindowsPath('full/Week 12/400937527 - Wake Forest vs NC State.json'),
#  '400937528 - Virginia Tech vs Pittsburgh.json': WindowsPath('full/Week 12/400937528 - Virginia Tech vs Pittsburgh.json'),
#  '400938661 - Southern Mississippi vs Charlotte.json': WindowsPath('full/Week 12/400938661 - Southern Mississippi vs Charlotte.json'),
#  '400938662 - Florida Atlantic vs Florida Intl.json': WindowsPath('full/Week 12/400938662 - Florida Atlantic vs Florida Intl.json'),
#  '400938663 - UTEP vs Louisiana Tech.json': WindowsPath('full/Week 12/400938663 - UTEP vs Louisiana Tech.json'),
#  '400938664 - UT San Antonio vs Marshall.json': WindowsPath('full/Week 12/400938664 - UT San Antonio vs Marshall.json'),
#  '400938665 - Western Kentucky vs Middle Tennessee.json': WindowsPath('full/Week 12/400938665 - Western Kentucky vs Middle Tennessee.json'),
#  '400938666 - Old Dominion vs Rice.json': WindowsPath('full/Week 12/400938666 - Old Dominion vs Rice.json'),
#  '400938895 - BYU vs UMass.json': WindowsPath('full/Week 12/400938895 - BYU vs UMass.json'),
#  '400941844 - Temple vs UCF.json': WindowsPath('full/Week 12/400941844 - Temple vs UCF.json'),
#  '400941845 - East Carolina vs Cincinnati.json': WindowsPath('full/Week 12/400941845 - East Carolina vs Cincinnati.json'),
#  '400941846 - Tulane vs Houston.json': WindowsPath('full/Week 12/400941846 - Tulane vs Houston.json'),
#  '400941847 - Memphis vs SMU.json': WindowsPath('full/Week 12/400941847 - Memphis vs SMU.json'),
#  '400941848 - South Florida vs Tulsa.json': WindowsPath('full/Week 12/400941848 - South Florida vs Tulsa.json'),
#  '400944875 - Arkansas State vs Texas State.json': WindowsPath('full/Week 12/400944875 - Arkansas State vs Texas State.json'),
#  '400944876 - Idaho vs Coastal Carolina.json': WindowsPath('full/Week 12/400944876 - Idaho vs Coastal Carolina.json'),
#  '400944877 - Georgia Southern vs South Alabama.json': WindowsPath('full/Week 12/400944877 - Georgia Southern vs South Alabama.json'),
#  '400944878 - Louisiana vs New Mexico State.json': WindowsPath('full/Week 12/400944878 - Louisiana vs New Mexico State.json'),
#  '400945019 - Kent State vs Central Michigan.json': WindowsPath('full/Week 12/400945019 - Kent State vs Central Michigan.json'),
#  '400945020 - Akron vs Ohio.json': WindowsPath('full/Week 12/400945020 - Akron vs Ohio.json'),
#  '400945021 - Miami (OH) vs Eastern Michigan.json': WindowsPath('full/Week 12/400945021 - Miami (OH) vs Eastern Michigan.json'),
#  '400945022 - Bowling Green vs Toledo.json': WindowsPath('full/Week 12/400945022 - Bowling Green vs Toledo.json'),
#  '400945023 - Northern Illinois vs Western Michigan.json': WindowsPath('full/Week 12/400945023 - Northern Illinois vs Western Michigan.json'),
#  '400945024 - Ball State vs Buffalo.json': WindowsPath('full/Week 12/400945024 - Ball State vs Buffalo.json'),
#  '400945300 - Boise State vs Air Force.json': WindowsPath('full/Week 12/400945300 - Boise State vs Air Force.json'),
#  '400945301 - Colorado State vs San Jose State.json': WindowsPath('full/Week 12/400945301 - Colorado State vs San Jose State.json'),
#  '400945302 - New Mexico vs UNLV.json': WindowsPath('full/Week 12/400945302 - New Mexico vs UNLV.json'),
#  '400945303 - Utah State vs Hawai_i.json': WindowsPath('full/Week 12/400945303 - Utah State vs Hawai_i.json'),
#  '400945304 - Wyoming vs Fresno State.json': WindowsPath('full/Week 12/400945304 - Wyoming vs Fresno State.json'),
#  '400945305 - San Diego State vs Nevada.json': WindowsPath('full/Week 12/400945305 - San Diego State vs Nevada.json'),
#  '400933930 - Mississippi State vs Ole Miss.json': WindowsPath('full/Week 13/400933930 - Mississippi State vs Ole Miss.json'),
#  '400933931 - Arkansas vs Missouri.json': WindowsPath('full/Week 13/400933931 - Arkansas vs Missouri.json'),
#  '400933932 - Auburn vs Alabama.json': WindowsPath('full/Week 13/400933932 - Auburn vs Alabama.json'),
#  '400933933 - Florida vs Florida State.json': WindowsPath('full/Week 13/400933933 - Florida vs Florida State.json'),
#  '400933934 - Georgia Tech vs Georgia.json': WindowsPath('full/Week 13/400933934 - Georgia Tech vs Georgia.json'),
#  '400933935 - Kentucky vs Louisville.json': WindowsPath('full/Week 13/400933935 - Kentucky vs Louisville.json'),
#  '400933936 - LSU vs Texas A_M.json': WindowsPath('full/Week 13/400933936 - LSU vs Texas A_M.json'),
#  '400933937 - South Carolina vs Clemson.json': WindowsPath('full/Week 13/400933937 - South Carolina vs Clemson.json'),
#  '400933938 - Tennessee vs Vanderbilt.json': WindowsPath('full/Week 13/400933938 - Tennessee vs Vanderbilt.json'),
#  '400934556 - TCU vs Baylor.json': WindowsPath('full/Week 13/400934556 - TCU vs Baylor.json'),
#  '400934557 - Texas vs Texas Tech.json': WindowsPath('full/Week 13/400934557 - Texas vs Texas Tech.json'),
#  '400934558 - Kansas State vs Iowa State.json': WindowsPath('full/Week 13/400934558 - Kansas State vs Iowa State.json'),
#  '400934559 - Oklahoma State vs Kansas.json': WindowsPath('full/Week 13/400934559 - Oklahoma State vs Kansas.json'),
#  '400934560 - Oklahoma vs West Virginia.json': WindowsPath('full/Week 13/400934560 - Oklahoma vs West Virginia.json'),
#  '400934583 - Stanford vs Notre Dame.json': WindowsPath('full/Week 13/400934583 - Stanford vs Notre Dame.json'),
#  '400935326 - UCLA vs California.json': WindowsPath('full/Week 13/400935326 - UCLA vs California.json'),
#  '400935327 - Oregon vs Oregon State.json': WindowsPath('full/Week 13/400935327 - Oregon vs Oregon State.json'),
#  '400935328 - Arizona State vs Arizona.json': WindowsPath('full/Week 13/400935328 - Arizona State vs Arizona.json'),
#  '400935329 - Utah vs Colorado.json': WindowsPath('full/Week 13/400935329 - Utah vs Colorado.json'),
#  '400935330 - Washington vs Washington State.json': WindowsPath('full/Week 13/400935330 - Washington vs Washington State.json'),
#  '400935417 - Nebraska vs Iowa.json': WindowsPath('full/Week 13/400935417 - Nebraska vs Iowa.json'),
#  '400935418 - Illinois vs Northwestern.json': WindowsPath('full/Week 13/400935418 - Illinois vs Northwestern.json'),
#  '400935419 - Maryland vs Penn State.json': WindowsPath('full/Week 13/400935419 - Maryland vs Penn State.json'),
#  '400935420 - Michigan vs Ohio State.json': WindowsPath('full/Week 13/400935420 - Michigan vs Ohio State.json'),
#  '400935421 - Minnesota vs Wisconsin.json': WindowsPath('full/Week 13/400935421 - Minnesota vs Wisconsin.json'),
#  '400935422 - Purdue vs Indiana.json': WindowsPath('full/Week 13/400935422 - Purdue vs Indiana.json'),
#  '400935423 - Rutgers vs Michigan State.json': WindowsPath('full/Week 13/400935423 - Rutgers vs Michigan State.json'),
#  '400937529 - Pittsburgh vs Miami.json': WindowsPath('full/Week 13/400937529 - Pittsburgh vs Miami.json'),
#  '400937530 - Virginia vs Virginia Tech.json': WindowsPath('full/Week 13/400937530 - Virginia vs Virginia Tech.json'),
#  '400937531 - Syracuse vs Boston College.json': WindowsPath('full/Week 13/400937531 - Syracuse vs Boston College.json'),
#  '400937532 - Wake Forest vs Duke.json': WindowsPath('full/Week 13/400937532 - Wake Forest vs Duke.json'),
#  '400937533 - NC State vs North Carolina.json': WindowsPath('full/Week 13/400937533 - NC State vs North Carolina.json'),
#  '400938667 - Charlotte vs Florida Atlantic.json': WindowsPath('full/Week 13/400938667 - Charlotte vs Florida Atlantic.json'),
#  '400938668 - Florida Intl vs Western Kentucky.json': WindowsPath('full/Week 13/400938668 - Florida Intl vs Western Kentucky.json'),
#  '400938669 - Louisiana Tech vs UT San Antonio.json': WindowsPath('full/Week 13/400938669 - Louisiana Tech vs UT San Antonio.json'),
#  '400938670 - Marshall vs Southern Mississippi.json': WindowsPath('full/Week 13/400938670 - Marshall vs Southern Mississippi.json'),
#  '400938671 - Middle Tennessee vs Old Dominion.json': WindowsPath('full/Week 13/400938671 - Middle Tennessee vs Old Dominion.json'),
#  '400938672 - Rice vs North Texas.json': WindowsPath('full/Week 13/400938672 - Rice vs North Texas.json'),
#  '400938673 - UAB vs UTEP.json': WindowsPath('full/Week 13/400938673 - UAB vs UTEP.json'),
#  '400941849 - UCF vs South Florida.json': WindowsPath('full/Week 13/400941849 - UCF vs South Florida.json'),
#  '400941850 - Houston vs Navy.json': WindowsPath('full/Week 13/400941850 - Houston vs Navy.json'),
#  '400941851 - Cincinnati vs Connecticut.json': WindowsPath('full/Week 13/400941851 - Cincinnati vs Connecticut.json'),
#  '400941852 - Memphis vs East Carolina.json': WindowsPath('full/Week 13/400941852 - Memphis vs East Carolina.json'),
#  '400941853 - Tulsa vs Temple.json': WindowsPath('full/Week 13/400941853 - Tulsa vs Temple.json'),
#  '400941854 - SMU vs Tulane.json': WindowsPath('full/Week 13/400941854 - SMU vs Tulane.json'),
#  '400944879 - Georgia State vs Appalachian State.json': WindowsPath('full/Week 13/400944879 - Georgia State vs Appalachian State.json'),
#  '400944880 - Louisiana Monroe vs Arkansas State.json': WindowsPath('full/Week 13/400944880 - Louisiana Monroe vs Arkansas State.json'),
#  '400944881 - Louisiana vs Georgia Southern.json': WindowsPath('full/Week 13/400944881 - Louisiana vs Georgia Southern.json'),
#  '400944882 - New Mexico State vs Idaho.json': WindowsPath('full/Week 13/400944882 - New Mexico State vs Idaho.json'),
#  '400944883 - Troy vs Texas State.json': WindowsPath('full/Week 13/400944883 - Troy vs Texas State.json'),
#  '400945025 - Eastern Michigan vs Bowling Green.json': WindowsPath('full/Week 13/400945025 - Eastern Michigan vs Bowling Green.json'),
#  '400945026 - Akron vs Kent State.json': WindowsPath('full/Week 13/400945026 - Akron vs Kent State.json'),
#  '400945027 - Ball State vs Miami (OH).json': WindowsPath('full/Week 13/400945027 - Ball State vs Miami (OH).json'),
#  '400945028 - Central Michigan vs Northern Illinois.json': WindowsPath('full/Week 13/400945028 - Central Michigan vs Northern Illinois.json'),
#  '400945029 - Buffalo vs Ohio.json': WindowsPath('full/Week 13/400945029 - Buffalo vs Ohio.json'),
#  '400945030 - Toledo vs Western Michigan.json': WindowsPath('full/Week 13/400945030 - Toledo vs Western Michigan.json'),
#  '400945306 - Air Force vs Utah State.json': WindowsPath('full/Week 13/400945306 - Air Force vs Utah State.json'),
#  '400945307 - Fresno State vs Boise State.json': WindowsPath('full/Week 13/400945307 - Fresno State vs Boise State.json'),
#  '400945308 - San Diego State vs New Mexico.json': WindowsPath('full/Week 13/400945308 - San Diego State vs New Mexico.json'),
#  '400945309 - San Jose State vs Wyoming.json': WindowsPath('full/Week 13/400945309 - San Jose State vs Wyoming.json'),
#  '400945310 - Hawai_i vs BYU.json': WindowsPath('full/Week 13/400945310 - Hawai_i vs BYU.json'),
#  '400945311 - Nevada vs UNLV.json': WindowsPath('full/Week 13/400945311 - Nevada vs UNLV.json'),
#  '400944884 - Appalachian State vs Louisiana.json': WindowsPath('full/Week 14/400944884 - Appalachian State vs Louisiana.json'),
#  '400944885 - Arkansas State vs Troy.json': WindowsPath('full/Week 14/400944885 - Arkansas State vs Troy.json'),
#  '400944886 - Coastal Carolina vs Georgia Southern.json': WindowsPath('full/Week 14/400944886 - Coastal Carolina vs Georgia Southern.json'),
#  '400944887 - Georgia State vs Idaho.json': WindowsPath('full/Week 14/400944887 - Georgia State vs Idaho.json'),
#  '400944888 - New Mexico State vs South Alabama.json': WindowsPath('full/Week 14/400944888 - New Mexico State vs South Alabama.json'),
#  '400955149 - USC vs Stanford.json': WindowsPath('full/Week 14/400955149 - USC vs Stanford.json'),
#  '400955150 - Toledo vs Akron.json': WindowsPath('full/Week 14/400955150 - Toledo vs Akron.json'),
#  '400955151 - UCF vs Memphis.json': WindowsPath('full/Week 14/400955151 - UCF vs Memphis.json'),
#  '400955152 - Florida Atlantic vs North Texas.json': WindowsPath('full/Week 14/400955152 - Florida Atlantic vs North Texas.json'),
#  '400955153 - Auburn vs Georgia.json': WindowsPath('full/Week 14/400955153 - Auburn vs Georgia.json'),
#  '400955154 - Boise State vs Fresno State.json': WindowsPath('full/Week 14/400955154 - Boise State vs Fresno State.json'),
#  '400955155 - Clemson vs Miami.json': WindowsPath('full/Week 14/400955155 - Clemson vs Miami.json'),
#  '400955156 - Wisconsin vs Ohio State.json': WindowsPath('full/Week 14/400955156 - Wisconsin vs Ohio State.json'),
#  '400955157 - Oklahoma vs TCU.json': WindowsPath('full/Week 14/400955157 - Oklahoma vs TCU.json'),
#  '400985387 - Florida Intl vs UMass.json': WindowsPath('full/Week 14/400985387 - Florida Intl vs UMass.json'),
#  '401000149 - Florida State vs Louisiana Monroe.json': WindowsPath('full/Week 14/401000149 - Florida State vs Louisiana Monroe.json'),
#  '400934572 - Navy vs Army.json': WindowsPath('full/Week 15/400934572 - Navy vs Army.json'),
#  '400933841 - Alabama vs Fresno State.json': WindowsPath('full/Week 2/400933841 - Alabama vs Fresno State.json'),
#  '400933842 - Arkansas vs TCU.json': WindowsPath('full/Week 2/400933842 - Arkansas vs TCU.json'),
#  '400933843 - Clemson vs Auburn.json': WindowsPath('full/Week 2/400933843 - Clemson vs Auburn.json'),
#  '400933845 - Notre Dame vs Georgia.json': WindowsPath('full/Week 2/400933845 - Notre Dame vs Georgia.json'),
#  '400933846 - Kentucky vs Eastern Kentucky.json': WindowsPath('full/Week 2/400933846 - Kentucky vs Eastern Kentucky.json'),
#  '400933847 - LSU vs Chattanooga.json': WindowsPath('full/Week 2/400933847 - LSU vs Chattanooga.json'),
#  '400933848 - Ole Miss vs UT Martin.json': WindowsPath('full/Week 2/400933848 - Ole Miss vs UT Martin.json'),
#  '400933849 - Louisiana Tech vs Mississippi State.json': WindowsPath('full/Week 2/400933849 - Louisiana Tech vs Mississippi State.json'),
#  '400933850 - Missouri vs South Carolina.json': WindowsPath('full/Week 2/400933850 - Missouri vs South Carolina.json'),
#  '400933851 - Tennessee vs Indiana State.json': WindowsPath('full/Week 2/400933851 - Tennessee vs Indiana State.json'),
#  '400933852 - Texas A_M vs Nicholls.json': WindowsPath('full/Week 2/400933852 - Texas A_M vs Nicholls.json'),
#  '400933853 - Vanderbilt vs Alabama A_M.json': WindowsPath('full/Week 2/400933853 - Vanderbilt vs Alabama A_M.json'),
#  '400934498 - Baylor vs UT San Antonio.json': WindowsPath('full/Week 2/400934498 - Baylor vs UT San Antonio.json'),
#  '400934499 - Iowa State vs Iowa.json': WindowsPath('full/Week 2/400934499 - Iowa State vs Iowa.json'),
#  '400934500 - Kansas vs Central Michigan.json': WindowsPath('full/Week 2/400934500 - Kansas vs Central Michigan.json'),
#  '400934501 - Kansas State vs Charlotte.json': WindowsPath('full/Week 2/400934501 - Kansas State vs Charlotte.json'),
#  '400934502 - Ohio State vs Oklahoma.json': WindowsPath('full/Week 2/400934502 - Ohio State vs Oklahoma.json'),
#  '400934503 - South Alabama vs Oklahoma State.json': WindowsPath('full/Week 2/400934503 - South Alabama vs Oklahoma State.json'),
#  '400934504 - Texas vs San Jose╠ü State.json': WindowsPath('full/Week 2/400934504 - Texas vs San Jose╠ü State.json'),
#  '400934505 - West Virginia vs East Carolina.json': WindowsPath('full/Week 2/400934505 - West Virginia vs East Carolina.json'),
#  '400934562 - Army vs Buffalo.json': WindowsPath('full/Week 2/400934562 - Army vs Buffalo.json'),
# ...
#  '400938635 - UAB vs Middle Tennessee.json': WindowsPath('full/Week 7/400938635 - UAB vs Middle Tennessee.json'),
#  '400938636 - North Texas vs UT San Antonio.json': WindowsPath('full/Week 7/400938636 - North Texas vs UT San Antonio.json'),
#  '400938637 - Southern Mississippi vs UTEP.json': WindowsPath('full/Week 7/400938637 - Southern Mississippi vs UTEP.json'),
#  '400941820 - UCF vs East Carolina.json': WindowsPath('full/Week 7/400941820 - UCF vs East Carolina.json'),
#  '400941821 - Temple vs Connecticut.json': WindowsPath('full/Week 7/400941821 - Temple vs Connecticut.json'),
#  '400941822 - Tulsa vs Houston.json': WindowsPath('full/Week 7/400941822 - Tulsa vs Houston.json'),
#  '400941823 - Memphis vs Navy.json': WindowsPath('full/Week 7/400941823 - Memphis vs Navy.json'),
#  '400941832 - South Florida vs Cincinnati.json': WindowsPath('full/Week 7/400941832 - South Florida vs Cincinnati.json'),
#  '400944851 - Troy vs South Alabama.json': WindowsPath('full/Week 7/400944851 - Troy vs South Alabama.json'),
#  '400944852 - Louisiana vs Texas State.json': WindowsPath('full/Week 7/400944852 - Louisiana vs Texas State.json'),
#  '400944853 - Idaho vs Appalachian State.json': WindowsPath('full/Week 7/400944853 - Idaho vs Appalachian State.json'),
#  '400944854 - Arkansas State vs Coastal Carolina.json': WindowsPath('full/Week 7/400944854 - Arkansas State vs Coastal Carolina.json'),
#  '400944855 - Georgia Southern vs New Mexico State.json': WindowsPath('full/Week 7/400944855 - Georgia Southern vs New Mexico State.json'),
#  '400944856 - Louisiana Monroe vs Georgia State.json': WindowsPath('full/Week 7/400944856 - Louisiana Monroe vs Georgia State.json'),
#  '400944994 - Western Michigan vs Akron.json': WindowsPath('full/Week 7/400944994 - Western Michigan vs Akron.json'),
#  '400944995 - Kent State vs Miami (OH).json': WindowsPath('full/Week 7/400944995 - Kent State vs Miami (OH).json'),
#  '400944996 - Buffalo vs Northern Illinois.json': WindowsPath('full/Week 7/400944996 - Buffalo vs Northern Illinois.json'),
#  '400944997 - Bowling Green vs Ohio.json': WindowsPath('full/Week 7/400944997 - Bowling Green vs Ohio.json'),
#  '400944998 - Central Michigan vs Toledo.json': WindowsPath('full/Week 7/400944998 - Central Michigan vs Toledo.json'),
#  '400945272 - Air Force vs UNLV.json': WindowsPath('full/Week 7/400945272 - Air Force vs UNLV.json'),
#  '400945273 - San Diego State vs Boise State.json': WindowsPath('full/Week 7/400945273 - San Diego State vs Boise State.json'),
#  '400945274 - Colorado State vs Nevada.json': WindowsPath('full/Week 7/400945274 - Colorado State vs Nevada.json'),
#  '400945275 - Fresno State vs New Mexico.json': WindowsPath('full/Week 7/400945275 - Fresno State vs New Mexico.json'),
#  '400945276 - Utah State vs Wyoming.json': WindowsPath('full/Week 7/400945276 - Utah State vs Wyoming.json'),
#  '400945277 - Hawai_i vs San Jose╠ü State.json': WindowsPath('full/Week 7/400945277 - Hawai_i vs San Jose╠ü State.json'),
#  '400981508 - Miami vs Georgia Tech.json': WindowsPath('full/Week 7/400981508 - Miami vs Georgia Tech.json'),
#  '400933893 - Alabama vs Tennessee.json': WindowsPath('full/Week 8/400933893 - Alabama vs Tennessee.json'),
#  '400933894 - Arkansas vs Auburn.json': WindowsPath('full/Week 8/400933894 - Arkansas vs Auburn.json'),
#  '400933895 - Ole Miss vs LSU.json': WindowsPath('full/Week 8/400933895 - Ole Miss vs LSU.json'),
#  '400933896 - Mississippi State vs Kentucky.json': WindowsPath('full/Week 8/400933896 - Mississippi State vs Kentucky.json'),
#  '400933897 - Missouri vs Idaho.json': WindowsPath('full/Week 8/400933897 - Missouri vs Idaho.json'),
#  '400934531 - Texas Tech vs Iowa State.json': WindowsPath('full/Week 8/400934531 - Texas Tech vs Iowa State.json'),
#  '400934532 - TCU vs Kansas.json': WindowsPath('full/Week 8/400934532 - TCU vs Kansas.json'),
#  '400934533 - Baylor vs West Virginia.json': WindowsPath('full/Week 8/400934533 - Baylor vs West Virginia.json'),
#  '400934534 - Kansas State vs Oklahoma.json': WindowsPath('full/Week 8/400934534 - Kansas State vs Oklahoma.json'),
#  '400934535 - Texas vs Oklahoma State.json': WindowsPath('full/Week 8/400934535 - Texas vs Oklahoma State.json'),
#  '400934568 - Army vs Temple.json': WindowsPath('full/Week 8/400934568 - Army vs Temple.json'),
#  '400934578 - Notre Dame vs USC.json': WindowsPath('full/Week 8/400934578 - Notre Dame vs USC.json'),
#  '400935300 - California vs Arizona.json': WindowsPath('full/Week 8/400935300 - California vs Arizona.json'),
#  '400935301 - Utah vs Arizona State.json': WindowsPath('full/Week 8/400935301 - Utah vs Arizona State.json'),
#  '400935302 - UCLA vs Oregon.json': WindowsPath('full/Week 8/400935302 - UCLA vs Oregon.json'),
#  '400935303 - Washington State vs Colorado.json': WindowsPath('full/Week 8/400935303 - Washington State vs Colorado.json'),
#  '400935383 - Michigan State vs Indiana.json': WindowsPath('full/Week 8/400935383 - Michigan State vs Indiana.json'),
#  '400935384 - Minnesota vs Illinois.json': WindowsPath('full/Week 8/400935384 - Minnesota vs Illinois.json'),
#  '400935385 - Northwestern vs Iowa.json': WindowsPath('full/Week 8/400935385 - Northwestern vs Iowa.json'),
#  '400935386 - Penn State vs Michigan.json': WindowsPath('full/Week 8/400935386 - Penn State vs Michigan.json'),
#  '400935387 - Rutgers vs Purdue.json': WindowsPath('full/Week 8/400935387 - Rutgers vs Purdue.json'),
#  '400935388 - Wisconsin vs Maryland.json': WindowsPath('full/Week 8/400935388 - Wisconsin vs Maryland.json'),
#  '400937498 - Virginia vs Boston College.json': WindowsPath('full/Week 8/400937498 - Virginia vs Boston College.json'),
#  '400937499 - Duke vs Pittsburgh.json': WindowsPath('full/Week 8/400937499 - Duke vs Pittsburgh.json'),
#  '400937500 - Florida State vs Louisville.json': WindowsPath('full/Week 8/400937500 - Florida State vs Louisville.json'),
#  '400937501 - Georgia Tech vs Wake Forest.json': WindowsPath('full/Week 8/400937501 - Georgia Tech vs Wake Forest.json'),
#  '400937502 - Miami vs Syracuse.json': WindowsPath('full/Week 8/400937502 - Miami vs Syracuse.json'),
#  '400937503 - Virginia Tech vs North Carolina.json': WindowsPath('full/Week 8/400937503 - Virginia Tech vs North Carolina.json'),
#  '400938638 - Charlotte vs UAB.json': WindowsPath('full/Week 8/400938638 - Charlotte vs UAB.json'),
#  '400938639 - Florida Atlantic vs North Texas.json': WindowsPath('full/Week 8/400938639 - Florida Atlantic vs North Texas.json'),
#  '400938640 - Louisiana Tech vs Southern Mississippi.json': WindowsPath('full/Week 8/400938640 - Louisiana Tech vs Southern Mississippi.json'),
#  '400938641 - Old Dominion vs Western Kentucky.json': WindowsPath('full/Week 8/400938641 - Old Dominion vs Western Kentucky.json'),
#  '400938642 - UT San Antonio vs Rice.json': WindowsPath('full/Week 8/400938642 - UT San Antonio vs Rice.json'),
#  '400938674 - Middle Tennessee vs Marshall.json': WindowsPath('full/Week 8/400938674 - Middle Tennessee vs Marshall.json'),
#  '400938892 - UMass vs Georgia Southern.json': WindowsPath('full/Week 8/400938892 - UMass vs Georgia Southern.json'),
#  '400941824 - Houston vs Memphis.json': WindowsPath('full/Week 8/400941824 - Houston vs Memphis.json'),
#  '400941825 - Navy vs UCF.json': WindowsPath('full/Week 8/400941825 - Navy vs UCF.json'),
#  '400941826 - Cincinnati vs SMU.json': WindowsPath('full/Week 8/400941826 - Cincinnati vs SMU.json'),
#  '400941827 - Connecticut vs Tulsa.json': WindowsPath('full/Week 8/400941827 - Connecticut vs Tulsa.json'),
#  '400941828 - East Carolina vs BYU.json': WindowsPath('full/Week 8/400941828 - East Carolina vs BYU.json'),
#  '400941829 - Tulane vs South Florida.json': WindowsPath('full/Week 8/400941829 - Tulane vs South Florida.json'),
#  '400944857 - Arkansas State vs Louisiana.json': WindowsPath('full/Week 8/400944857 - Arkansas State vs Louisiana.json'),
#  '400944858 - Appalachian State vs Coastal Carolina.json': WindowsPath('full/Week 8/400944858 - Appalachian State vs Coastal Carolina.json'),
#  '400944859 - South Alabama vs Louisiana Monroe.json': WindowsPath('full/Week 8/400944859 - South Alabama vs Louisiana Monroe.json'),
#  '400944860 - Georgia State vs Troy.json': WindowsPath('full/Week 8/400944860 - Georgia State vs Troy.json'),
#  '400944999 - Toledo vs Akron.json': WindowsPath('full/Week 8/400944999 - Toledo vs Akron.json'),
#  '400945000 - Miami (OH) vs Buffalo.json': WindowsPath('full/Week 8/400945000 - Miami (OH) vs Buffalo.json'),
#  '400945001 - Ball State vs Central Michigan.json': WindowsPath('full/Week 8/400945001 - Ball State vs Central Michigan.json'),
#  '400945002 - Ohio vs Kent State.json': WindowsPath('full/Week 8/400945002 - Ohio vs Kent State.json'),
#  '400945003 - Bowling Green vs Northern Illinois.json': WindowsPath('full/Week 8/400945003 - Bowling Green vs Northern Illinois.json'),
#  '400945004 - Eastern Michigan vs Western Michigan.json': WindowsPath('full/Week 8/400945004 - Eastern Michigan vs Western Michigan.json'),
#  '400945278 - Nevada vs Air Force.json': WindowsPath('full/Week 8/400945278 - Nevada vs Air Force.json'),
#  '400945279 - Boise State vs Wyoming.json': WindowsPath('full/Week 8/400945279 - Boise State vs Wyoming.json'),
#  '400945280 - New Mexico vs Colorado State.json': WindowsPath('full/Week 8/400945280 - New Mexico vs Colorado State.json'),
#  '400945281 - UNLV vs Utah State.json': WindowsPath('full/Week 8/400945281 - UNLV vs Utah State.json'),
#  '400945282 - San Diego State vs Fresno State.json': WindowsPath('full/Week 8/400945282 - San Diego State vs Fresno State.json'),
#  '400933898 - Florida vs Georgia.json': WindowsPath('full/Week 9/400933898 - Florida vs Georgia.json'),
#  '400933899 - Kentucky vs Tennessee.json': WindowsPath('full/Week 9/400933899 - Kentucky vs Tennessee.json'),
#  '400933900 - Ole Miss vs Arkansas.json': WindowsPath('full/Week 9/400933900 - Ole Miss vs Arkansas.json'),
#  '400933901 - Connecticut vs Missouri.json': WindowsPath('full/Week 9/400933901 - Connecticut vs Missouri.json'),
#  '400933902 - South Carolina vs Vanderbilt.json': WindowsPath('full/Week 9/400933902 - South Carolina vs Vanderbilt.json'),
#  '400933903 - Texas A_M vs Mississippi State.json': WindowsPath('full/Week 9/400933903 - Texas A_M vs Mississippi State.json'),
#  '400934536 - Kansas vs Kansas State.json': WindowsPath('full/Week 9/400934536 - Kansas vs Kansas State.json'),
#  '400934537 - West Virginia vs Oklahoma State.json': WindowsPath('full/Week 9/400934537 - West Virginia vs Oklahoma State.json'),
#  '400934538 - Baylor vs Texas.json': WindowsPath('full/Week 9/400934538 - Baylor vs Texas.json'),
#  '400934539 - Oklahoma vs Texas Tech.json': WindowsPath('full/Week 9/400934539 - Oklahoma vs Texas Tech.json'),
#  '400934540 - Iowa State vs TCU.json': WindowsPath('full/Week 9/400934540 - Iowa State vs TCU.json'),
#  '400934579 - Notre Dame vs NC State.json': WindowsPath('full/Week 9/400934579 - Notre Dame vs NC State.json'),
#  '400935304 - Oregon State vs Stanford.json': WindowsPath('full/Week 9/400935304 - Oregon State vs Stanford.json'),
#  '400935305 - Arizona vs Washington State.json': WindowsPath('full/Week 9/400935305 - Arizona vs Washington State.json'),
#  '400935306 - Arizona State vs USC.json': WindowsPath('full/Week 9/400935306 - Arizona State vs USC.json'),
#  '400935307 - Washington vs UCLA.json': WindowsPath('full/Week 9/400935307 - Washington vs UCLA.json'),
#  '400935308 - Colorado vs California.json': WindowsPath('full/Week 9/400935308 - Colorado vs California.json'),
#  '400935309 - Oregon vs Utah.json': WindowsPath('full/Week 9/400935309 - Oregon vs Utah.json'),
#  '400935389 - Northwestern vs Michigan State.json': WindowsPath('full/Week 9/400935389 - Northwestern vs Michigan State.json'),
#  '400935390 - Illinois vs Wisconsin.json': WindowsPath('full/Week 9/400935390 - Illinois vs Wisconsin.json'),
#  '400935391 - Iowa vs Minnesota.json': WindowsPath('full/Week 9/400935391 - Iowa vs Minnesota.json'),
#  '400935392 - Maryland vs Indiana.json': WindowsPath('full/Week 9/400935392 - Maryland vs Indiana.json'),
#  '400935393 - Michigan vs Rutgers.json': WindowsPath('full/Week 9/400935393 - Michigan vs Rutgers.json'),
#  '400935394 - Ohio State vs Penn State.json': WindowsPath('full/Week 9/400935394 - Ohio State vs Penn State.json'),
#  '400935395 - Purdue vs Nebraska.json': WindowsPath('full/Week 9/400935395 - Purdue vs Nebraska.json'),
#  '400937504 - Boston College vs Florida State.json': WindowsPath('full/Week 9/400937504 - Boston College vs Florida State.json'),
#  '400937505 - Clemson vs Georgia Tech.json': WindowsPath('full/Week 9/400937505 - Clemson vs Georgia Tech.json'),
#  '400937506 - Virginia Tech vs Duke.json': WindowsPath('full/Week 9/400937506 - Virginia Tech vs Duke.json'),
#  '400937507 - Wake Forest vs Louisville.json': WindowsPath('full/Week 9/400937507 - Wake Forest vs Louisville.json'),
#  '400937508 - North Carolina vs Miami.json': WindowsPath('full/Week 9/400937508 - North Carolina vs Miami.json'),
#  '400937509 - Pittsburgh vs Virginia.json': WindowsPath('full/Week 9/400937509 - Pittsburgh vs Virginia.json'),
#  '400938643 - Marshall vs Florida Intl.json': WindowsPath('full/Week 9/400938643 - Marshall vs Florida Intl.json'),
#  '400938644 - Western Kentucky vs Florida Atlantic.json': WindowsPath('full/Week 9/400938644 - Western Kentucky vs Florida Atlantic.json'),
#  '400938645 - Rice vs Louisiana Tech.json': WindowsPath('full/Week 9/400938645 - Rice vs Louisiana Tech.json'),
#  '400938646 - North Texas vs Old Dominion.json': WindowsPath('full/Week 9/400938646 - North Texas vs Old Dominion.json'),
#  '400938647 - Southern Mississippi vs UAB.json': WindowsPath('full/Week 9/400938647 - Southern Mississippi vs UAB.json'),
#  '400938648 - UTEP vs UT San Antonio.json': WindowsPath('full/Week 9/400938648 - UTEP vs UT San Antonio.json'),
#  '400938893 - UMass vs Appalachian State.json': WindowsPath('full/Week 9/400938893 - UMass vs Appalachian State.json'),
#  '400941830 - Memphis vs Tulane.json': WindowsPath('full/Week 9/400941830 - Memphis vs Tulane.json'),
#  '400941831 - SMU vs Tulsa.json': WindowsPath('full/Week 9/400941831 - SMU vs Tulsa.json'),
#  '400941839 - South Florida vs Houston.json': WindowsPath('full/Week 9/400941839 - South Florida vs Houston.json'),
#  '400944861 - Georgia State vs South Alabama.json': WindowsPath('full/Week 9/400944861 - Georgia State vs South Alabama.json'),
#  '400944862 - New Mexico State vs Arkansas State.json': WindowsPath('full/Week 9/400944862 - New Mexico State vs Arkansas State.json'),
#  '400944863 - Coastal Carolina vs Texas State.json': WindowsPath('full/Week 9/400944863 - Coastal Carolina vs Texas State.json'),
#  '400944864 - Troy vs Georgia Southern.json': WindowsPath('full/Week 9/400944864 - Troy vs Georgia Southern.json'),
#  '400944865 - Idaho vs Louisiana Monroe.json': WindowsPath('full/Week 9/400944865 - Idaho vs Louisiana Monroe.json'),
#  '400945005 - Northern Illinois vs Eastern Michigan.json': WindowsPath('full/Week 9/400945005 - Northern Illinois vs Eastern Michigan.json'),
#  '400945006 - Ball State vs Toledo.json': WindowsPath('full/Week 9/400945006 - Ball State vs Toledo.json'),
#  '400945007 - Akron vs Buffalo.json': WindowsPath('full/Week 9/400945007 - Akron vs Buffalo.json'),
#  '400945283 - Colorado State vs Air Force.json': WindowsPath('full/Week 9/400945283 - Colorado State vs Air Force.json'),
#  '400945284 - Utah State vs Boise State.json': WindowsPath('full/Week 9/400945284 - Utah State vs Boise State.json'),
#  '400945285 - Wyoming vs New Mexico.json': WindowsPath('full/Week 9/400945285 - Wyoming vs New Mexico.json'),
#  '400945286 - Fresno State vs UNLV.json': WindowsPath('full/Week 9/400945286 - Fresno State vs UNLV.json'),
#  '400945287 - Hawai_i vs San Diego State.json': WindowsPath('full/Week 9/400945287 - Hawai_i vs San Diego State.json'),
#  '400945288 - BYU vs San Jose State.json': WindowsPath('full/Week 9/400945288 - BYU vs San Jose State.json'),
#  '400986609 - UCF vs Austin Peay.json': WindowsPath('full/Week 9/400986609 - UCF vs Austin Peay.json'),
#  '.ipynb_checkpoints': WindowsPath('full/Week 3/.ipynb_checkpoints/400937467 - Virginia vs Connecticut-checkpoint.json')}

# %% [markdown]
# ## Question 1
# How many games are in the data set?

# %%
answer_dict = {}
answer_dict["q1"] = len(all_game_dict)
#872
answer_dict
# Out:
# {'q1': 872}

# %% [markdown]
# ## Question 2
# What are topmost keys for each game file?

# %%
game = load_json(all_game_dict['400933827 - Alabama vs Florida State.json'])
top_keys = game.keys()

answer_dict["q2.a"] = list(top_keys)
# Out:
# {'q1': 872,
#  'q2.a': ['scoringPlays',
#   'videos',
#   'drives',
#   'teams',
#   'id',
#   'competitions',
#   'season',
#   'week'],
#  'q2.b': 'Teams appear to be referenced consistently and there are no duplicate games in the list. There are a couple of games that seem to be mixed up in there where it shows EAST vs. WEST, National vs. American, and NORTH vs. SOUTH which are not college football teams. so I decided to remove those games.',
#  'q3': 'yes',
#  'q3.1': ['Abilene Christian',
#   'Air Force',
#   'Akron',
#   'Alabama',
#   'Alabama A_M',
#   'Alabama State',
#   'Albany',
#   'Alcorn State',
#   'Appalachian State',
#   'Arizona',
#   'Arizona State',
#   'Arkansas',
#   'Arkansas State',
#   'Army',
#   'Auburn',
#   'Austin Peay',
#   'BYU',
#   'Ball State',
#   'Baylor',
#   'Boise State',
#   'Boston College',
#   'Bowling Green',
#   'Buffalo',
#   'California',
#   'Central Arkansas',
#   'Central Connecticut',
#   'Central Michigan',
#   'Charleston Southern',
#   'Charlotte',
#   'Chattanooga',
#   'Cincinnati',
#   'Clemson',
#   'Coastal Carolina',
#   'Colgate',
#   'Colorado',
#   'Colorado State',
#   'Connecticut',
#   'Delaware',
#   'Delaware State',
#   'Duke',
#   'East Carolina',
#   'Eastern Illinois',
#   'Eastern Kentucky',
#   'Eastern Michigan',
#   'Eastern Washington',
#   'Elon',
#   'Florida',
#   'Florida A_M',
#   'Florida Atlantic',
#   'Florida Intl',
#   'Florida State',
#   'Fordham',
#   'Fresno State',
#   'Furman',
#   'Georgia',
#   'Georgia Southern',
#   'Georgia State',
#   'Georgia Tech',
#   'Grambling',
#   'Hampton',
#   'Hawai_i',
#   'Holy Cross',
#   'Houston',
#   'Houston Baptist',
#   'Howard',
#   'Idaho',
#   'Idaho State',
#   'Illinois',
#   'Incarnate Word',
#   'Indiana',
#   'Indiana State',
#   'Iowa',
#   'Iowa State',
#   'Jackson State',
#   'Jacksonville State',
#   'James Madison',
#   'Kansas',
#   'Kansas State',
#   'Kent State',
#   'Kentucky',
#   'LSU',
#   'Lamar',
#   'Liberty',
#   'Louisiana',
#   'Louisiana Monroe',
#   'Louisiana Tech',
#   'Louisville',
#   'Maine',
#   'Marshall',
#   'Maryland',
#   'Memphis',
#   'Mercer',
#   'Miami',
#   'Miami (OH)',
#   'Michigan',
#   'Michigan State',
#   'Middle Tennessee',
#   'Minnesota',
#   'Mississippi State',
#   'Missouri',
#   'Missouri State',
#   'Montana',
#   'Montana State',
#   'Morgan State',
#   'Murray State',
#   'NC State',
#   'Navy',
#   'Nebraska',
#   'Nevada',
#   'New Hampshire',
#   'New Mexico',
#   'New Mexico State',
#   'Nicholls',
#   'North Carolina',
#   'North Carolina A_T',
#   'North Carolina Central',
#   'North Dakota',
#   'North Texas',
#   'Northern Arizona',
#   'Northern Colorado',
#   'Northern Illinois',
#   'Northern Iowa',
#   'Northwestern',
#   'Northwestern State',
#   'Notre Dame',
#   'Ohio',
#   'Ohio State',
#   'Oklahoma',
#   'Oklahoma State',
#   'Old Dominion',
#   'Ole Miss',
#   'Oregon',
#   'Oregon State',
#   'Penn State',
#   'Pittsburgh',
#   'Portland State',
#   'Presbyterian College',
#   'Purdue',
#   'Rhode Island',
#   'Rice',
#   'Rutgers',
#   'SMU',
#   'Sacramento State',
#   'Samford',
#   'San Diego State',
#   'San Jose State',
#   'Savannah State',
#   'South Alabama',
#   'South Carolina',
#   'South Dakota',
#   'South Florida',
#   'Southeast Missouri State',
#   'Southern',
#   'Southern Illinois',
#   'Southern Mississippi',
#   'Southern Utah',
#   'Stanford',
#   'Stony Brook',
#   'Syracuse',
#   'TCU',
#   'Temple',
#   'Tennessee',
#   'Tennessee State',
#   'Tennessee Tech',
#   'Texas',
#   'Texas A_M',
#   'Texas State',
#   'Texas Tech',
#   'The Citadel',
#   'Toledo',
#   'Towson',
#   'Troy',
#   'Tulane',
#   'Tulsa',
#   'UAB',
#   'UC Davis',
#   'UCF',
#   'UCLA',
#   'UMass',
#   'UNLV',
#   'USC',
#   'UT Martin',
#   'UT San Antonio',
#   'UTEP',
#   'Utah',
#   'Utah State',
#   'VMI',
#   'Vanderbilt',
#   'Villanova',
#   'Virginia',
#   'Virginia Tech',
#   'Wagner',
#   'Wake Forest',
#   'Washington',
#   'Washington State',
#   'Weber State',
#   'West Virginia',
#   'Western Carolina',
#   'Western Illinois',
#   'Western Kentucky',
#   'Western Michigan',
#   'William _ Mary',
#   'Wisconsin',
#   'Wofford',
#   'Wyoming',
#   'Youngstown State'],
#  'q4': 'yes',
#  'q4.1': "I looked at a few things to confirm. First skimming over the teams list, all the team names were familiar. There were 6 team names that were unusual (EAST, WEST, SOUTH, NORTH, American, and National). They were all in week one and were playing one another which made me think they could be a non-season all-star game so I chose to remove those 3 games since the focus seems to be the college football season games. I checked to see if there were duplicate games but there weren't any. The number of games (871) and teams (206) also appears to be reasonable as I assume some of the non-conference games a FBS school plays will be against non-FBS opponents who only appear once in the dataset and some smaller schools may not always have their game on ESPN so that may explain why the ratio of games to teams is lower than the actual number of games a team plays in a season.",
#  'q5': 206,
#  'q6': 'Yes',
#  'q6+1': "Alabama wasn't the worst team but their ratio of made field goals to missed field goals was below average. Alabama made 18 and missed 8 field goals which is better than a school like South Carolina who only made 15 but missed 13. In the regular season, Alabama's ratio was 2.25 which is less than the average ratio which was 3.22 though that may include some teams that were only represented in the list once because they are a lower level school. According to the data, Alabama did miss more often than the average school.",
#  'q7': 46,
#  'q8': ['Fresno State Bulldogs'],
#  'q9': ['Missouri Tigers',
#   'Charleston Southern Buccaneers',
#   'Incarnate Word Cardinals',
#   'Utah State Aggies'],
#  'q10': ['Team: Boise State Broncos, Opponent: Oregon Ducks, Quarter: 2, Time: 0:07, Description: Tyree Robinson 100 Yd Interception Return (Aidan Schneider Kick)',
#   'Team: New Mexico State Aggies, Opponent: Utah State Aggies, Quarter: 1, Time: 10:47, Description: Jason Huntley 100 Yd Kickoff Return (Dylan Brown Kick)',
#   'Team: Western Michigan Broncos, Opponent: USC Trojans, Quarter: 4, Time: 7:54, Description: Michael Brown kickoff for 65 yds , Darius Phillips return for 100 yds for a TD, (Josh Grant KICK)',
#   'Team: Oregon Ducks, Opponent: Southern Utah Thunderbirds, Quarter: 1, Time: 14:47, Description: Keita Calhoun kickoff for 65 yds , Tony Brooks-James return for 100 yds for a TD, (Aidan Schneider KICK)',
#   'Team: New Mexico Lobos, Opponent: Texas A&M Aggies, Quarter: 2, Time: 1:24, Description: Drew Riethman kickoff for 65 yds , Elijah Lilly return for 100 yds for a TD (Jason Sanders KICK)',
#   'Team: Minnesota Golden Gophers, Opponent: Nebraska Cornhuskers, Quarter: 1, Time: 14:47, Description: Drew Brown kickoff for 65 yds , Rodney Smith return for 100 yds for a TD, (Emmit Carpenter KICK)',
#   'Team: San Jose State Spartans, Opponent: Nevada Wolf Pack, Quarter: 2, Time: 7:51, Description: Montel Aaron pass intercepted for a TD Dameon Baber return for 100 yds for a TD, (Spencer Pettit KICK)',
#   'Team: San Diego State Aztecs, Opponent: Nevada Wolf Pack, Quarter: 4, Time: 13:30, Description: Rashaad Penny 100 Yd Kickoff Return (John Baron II Kick)',
#   'Team: Memphis Tigers, Opponent: East Carolina Pirates, Quarter: 3, Time: 6:56, Description: Caleb Pratt kickoff for 65 yds , Tony Pollard return for 100 yds for a TD (Riley Patterson KICK)',
#   'Team: Arkansas State Red Wolves, Opponent: Troy Trojans, Quarter: 4, Time: 7:46, Description: Justice Hansen pass intercepted for a TD Marcus Jones return for 100 yds for a TD, (Tyler Sumpter KICK)',
#   'Team: Western Michigan Broncos, Opponent: Michigan State Spartans, Quarter: 4, Time: 10:37, Description: Brett Scanlon kickoff for 65 yds , Darius Phillips return for 100 yds for a TD, (Josh Grant KICK)',
#   'Team: Old Dominion Monarchs, Opponent: North Carolina Tar Heels, Quarter: 2, Time: 8:00, Description: Freeman Jones kickoff for 65 yds , Isaiah Harper return for 100 yds for a TD (Nick Rice KICK)',
#   'Team: Texas A&M Aggies, Opponent: Arkansas Razorbacks, Quarter: 4, Time: 5:10, Description: Connor Limpert kickoff for 65 yds , Christian Kirk return for 100 yds for a TD, (Daniel LaCamera KICK)',
#   'Team: Memphis Tigers, Opponent: Southern Illinois Salukis, Quarter: 3, Time: 0:05, Description: Nico Gualdoni kickoff for 65 yds , Tony Pollard return for 100 yds for a TD (Riley Patterson KICK)',
#   'Team: Maryland Terrapins, Opponent: Ohio State Buckeyes, Quarter: 1, Time: 9:40, Description: Sean Nuernberger kickoff for 65 yds , Ty Johnson return for 100 yds for a TD, (Henry Darmstadter KICK)',
#   "Team: Arkansas Razorbacks, Opponent: Auburn Tigers, Quarter: 3, Time: 3:57, Description: Daniel Carlson kickoff for 65 yds , De'Vion Warren return for 100 yds for a TD (Connor Limpert KICK)",
#   'Team: California Golden Bears, Opponent: Colorado Buffaloes, Quarter: 4, Time: 2:34, Description: Ross Bowers pass intercepted for a TD Nick Fisher return for 100 yds for a TD (James Stefanou KICK)'],
#  'q11': "Alabama's first drive of the season went for 34 yards. Damien Harris run for 34 yds to the FlaSt 41 for a 1ST down. Alabama's last drive of the season went for 41 yards. DeVonta Smith 41 Yd pass from Tua Tagovailoa .",
#  'q12': 54}

# %% [markdown]
# One of the challenges in data analysis is that the data being analyzed may have irregularities or errors that impact the accuracy of the results. For example, does that data set you've been given represent ALL games in the 2017 season? (This is not a question I need you to answer. It's just an example.) Although verifying the accuracy of the data is an important step, we will limit our scope to the titles of the files.
#
#
# Within the data set you've been given, are all teams refenced the same way (e.g., Texas A&M, Texas A and M, Texas A & M)? Are teams or competitions referenced more than once? To help answer this question, provide a python list of the teams represented in this data set, sorted alphabetically. Examine the file names to determine if a football game (i.e., competition) is duplicated.

# %%
# Testing for duplicate games by first creating a set of the list with all games
unique_game_list = set(all_game_list)
# If the unique game list and full game list are equal length then there would be no duplicates
if len(all_game_list) == len(unique_game_list):
    print("No duplicate games found")
else:
    print("Duplicate games found")
# Out:
# Duplicate games found

# %%
answer_dict["q2.b"] = "Teams appear to be referenced consistently and there are no duplicate games in the list. There are a couple of games that seem to be mixed up in there where it shows EAST vs. WEST, National vs. American, and NORTH vs. SOUTH which are not college football teams. so I decided to remove those games."

# %% [markdown]
# ## Question 3
# Are all teams referenced consistently? (yes/no)

# %%
answer_dict["q3"] = "yes"

# %% [markdown]
# ### Question 3.1
# Provide a Python list of all the teams represented in the files, sorted alphabetically.

# %%
# Create an empty team list
team_list = []
#create variables that will search and find regex to find all teams in the file
#home team
pattern_home = re.compile(r'^\d+\s*-\s*([\w\s()]+)\s+vs\s+[\w\s()]+\.json$')
#away team
pattern_away = re.compile(r'^\d+\s*-\s*[\w\s()]+\s+vs\s+([\w\s()]+)\.json$')
# a for loop that gets the name of the file which I had put in a list earlier and searches the file name for the home and away team
try:
    for game in all_game_list:
        #search home team
        home_team = re.match(pattern_home, game)
        #search away team
        away_team = re.match(pattern_away, game)
        #add teams to the team list if found
        if home_team:
            team_list.append(home_team.group(1))
        if away_team:
            team_list.append(away_team.group(1))
except Exception as e:
    print(f"An error occurred: {e}")
#use set to remove duplicates
unique_team_list = set(team_list)
answer_dict["q3.1"] = sorted(set(team_list))

# %% [markdown]
# ## Question 4
# Does the data seem reliable?
# * 'yes' or 'no'

# %%
answer_dict["q4"] = "yes"

# %% [markdown]
# ### Question 4.1
# Write a sentence or two in support of how you answered question four. It must be based on quantifiable reasons obtained from the data set. If you fixed anything in the data set, explain what you did and why.

# %%
#Removing uneccessary teams. Could only use this once since it removes the file from file_path and would draw an error after
#list = ['full/Week 1/400953746 - SOUTH vs NORTH.json',
# 'full/Week 1/400953747 - WEST vs EAST.json',
# 'full/Week 1/401003756 - National vs American.json',]
#for i in list:
#    if os.path.exists(i):
#       os.remove(i)
#    else:
#       print("file path don't exist")

# %%
answer_dict["q4.1"] = "I looked at a few things to confirm. First skimming over the teams list, all the team names were familiar. There were 6 team names that were unusual (EAST, WEST, SOUTH, NORTH, American, and National). They were all in week one and were playing one another which made me think they could be a non-season all-star game so I chose to remove those 3 games since the focus seems to be the college football season games. I checked to see if there were duplicate games but there weren't any. The number of games (871) and teams (206) also appears to be reasonable as I assume some of the non-conference games a FBS school plays will be against non-FBS opponents who only appear once in the dataset and some smaller schools may not always have their game on ESPN so that may explain why the ratio of games to teams is lower than the actual number of games a team plays in a season."

# %%
try:
    if len(all_game_list) == len(unique_game_list):
        print("No duplicate games found")
    else:
        print("Duplicate games found")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Duplicate games found

# %% [markdown]
# ## Question 5
# How many unique teams are represented in the data?

# %%
answer_dict["q5"] = len(unique_team_list)
answer_dict
# Out:
# {'q1': 872,
#  'q2.a': dict_keys(['scoringPlays', 'videos', 'drives', 'teams', 'id', 'competitions', 'season', 'week']),
#  'q2.b': 'Teams appear to be referenced consistently and there are no duplicate games in the list. There are a couple of games that seem to be mixed up in there where it shows EAST vs. WEST, National vs. American, and NORTH vs. SOUTH which are not college football teams. so I decided to remove those games.',
#  'q3': 'yes',
#  'q3.1': ['Abilene Christian',
#   'Air Force',
#   'Akron',
#   'Alabama',
#   'Alabama A_M',
#   'Alabama State',
#   'Albany',
#   'Alcorn State',
#   'Appalachian State',
#   'Arizona',
#   'Arizona State',
#   'Arkansas',
#   'Arkansas State',
#   'Army',
#   'Auburn',
#   'Austin Peay',
#   'BYU',
#   'Ball State',
#   'Baylor',
#   'Boise State',
#   'Boston College',
#   'Bowling Green',
#   'Buffalo',
#   'California',
#   'Central Arkansas',
#   'Central Connecticut',
#   'Central Michigan',
#   'Charleston Southern',
#   'Charlotte',
#   'Chattanooga',
#   'Cincinnati',
#   'Clemson',
#   'Coastal Carolina',
#   'Colgate',
#   'Colorado',
#   'Colorado State',
#   'Connecticut',
#   'Delaware',
#   'Delaware State',
#   'Duke',
#   'East Carolina',
#   'Eastern Illinois',
#   'Eastern Kentucky',
#   'Eastern Michigan',
#   'Eastern Washington',
#   'Elon',
#   'Florida',
#   'Florida A_M',
#   'Florida Atlantic',
#   'Florida Intl',
#   'Florida State',
#   'Fordham',
#   'Fresno State',
#   'Furman',
#   'Georgia',
#   'Georgia Southern',
#   'Georgia State',
#   'Georgia Tech',
#   'Grambling',
#   'Hampton',
#   'Hawai_i',
#   'Holy Cross',
#   'Houston',
#   'Houston Baptist',
#   'Howard',
#   'Idaho',
#   'Idaho State',
#   'Illinois',
#   'Incarnate Word',
#   'Indiana',
#   'Indiana State',
#   'Iowa',
#   'Iowa State',
#   'Jackson State',
#   'Jacksonville State',
#   'James Madison',
#   'Kansas',
#   'Kansas State',
#   'Kent State',
#   'Kentucky',
#   'LSU',
#   'Lamar',
#   'Liberty',
#   'Louisiana',
#   'Louisiana Monroe',
#   'Louisiana Tech',
#   'Louisville',
#   'Maine',
#   'Marshall',
#   'Maryland',
#   'Memphis',
#   'Mercer',
#   'Miami',
#   'Miami (OH)',
#   'Michigan',
#   'Michigan State',
#   'Middle Tennessee',
#   'Minnesota',
#   'Mississippi State',
#   'Missouri',
#   'Missouri State',
#   'Montana',
#   'Montana State',
#   'Morgan State',
#   'Murray State',
#   'NC State',
#   'Navy',
#   'Nebraska',
#   'Nevada',
#   'New Hampshire',
#   'New Mexico',
#   'New Mexico State',
#   'Nicholls',
#   'North Carolina',
#   'North Carolina A_T',
#   'North Carolina Central',
#   'North Dakota',
#   'North Texas',
#   'Northern Arizona',
#   'Northern Colorado',
#   'Northern Illinois',
#   'Northern Iowa',
#   'Northwestern',
#   'Northwestern State',
#   'Notre Dame',
#   'Ohio',
#   'Ohio State',
#   'Oklahoma',
#   'Oklahoma State',
#   'Old Dominion',
#   'Ole Miss',
#   'Oregon',
#   'Oregon State',
#   'Penn State',
#   'Pittsburgh',
#   'Portland State',
#   'Presbyterian College',
#   'Purdue',
#   'Rhode Island',
#   'Rice',
#   'Rutgers',
#   'SMU',
#   'Sacramento State',
#   'Samford',
#   'San Diego State',
#   'San Jose State',
#   'Savannah State',
#   'South Alabama',
#   'South Carolina',
#   'South Dakota',
#   'South Florida',
#   'Southeast Missouri State',
#   'Southern',
#   'Southern Illinois',
#   'Southern Mississippi',
#   'Southern Utah',
#   'Stanford',
#   'Stony Brook',
#   'Syracuse',
#   'TCU',
#   'Temple',
#   'Tennessee',
#   'Tennessee State',
#   'Tennessee Tech',
#   'Texas',
#   'Texas A_M',
#   'Texas State',
#   'Texas Tech',
#   'The Citadel',
#   'Toledo',
#   'Towson',
#   'Troy',
#   'Tulane',
#   'Tulsa',
#   'UAB',
#   'UC Davis',
#   'UCF',
#   'UCLA',
#   'UMass',
#   'UNLV',
#   'USC',
#   'UT Martin',
#   'UT San Antonio',
#   'UTEP',
#   'Utah',
#   'Utah State',
#   'VMI',
#   'Vanderbilt',
#   'Villanova',
#   'Virginia',
#   'Virginia Tech',
#   'Wagner',
#   'Wake Forest',
#   'Washington',
#   'Washington State',
#   'Weber State',
#   'West Virginia',
#   'Western Carolina',
#   'Western Illinois',
#   'Western Kentucky',
#   'Western Michigan',
#   'William _ Mary',
#   'Wisconsin',
#   'Wofford',
#   'Wyoming',
#   'Youngstown State'],
#  'q4': 'yes',
#  'q4.1': "I looked at a few things to confirm. First skimming over the teams list, all the team names were familiar. There were 6 team names that were unusual (EAST, WEST, SOUTH, NORTH, American, and National). They were all in week one and were playing one another which made me think they could be a non-season all-star game so I chose to remove those 3 games since the focus seems to be the college football season games. I checked to see if there were duplicate games but there weren't any. The number of games (871) and teams (206) also appears to be reasonable as I assume some of the non-conference games a FBS school plays will be against non-FBS opponents who only appear once in the dataset and some smaller schools may not always have their game on ESPN so that may explain why the ratio of games to teams is lower than the actual number of games a team plays in a season.",
#  'q5': 206}

# %% [markdown]
# ## Question 6
# Alabama has not always been blessed with strong placekickers. Is there evidence in the 2017 season that Alabama misses field goals more often than other teams nationwide?
# qn = 'yes' or 'no'
# qn+1 = Write a sentence or two supporting how you answered qn. It must include quantifiable reasons obtained from the data set.

# %% [markdown]
# # Get Missed FGs

# %%
#Dictionary to hold missed FGs
missed_fg_count = {}

try:
    # get the key value and file_path from the file and iterate through them
    for game, game_path in all_game_dict.items():
        # get the contents from game file
        current_data = load_json(game_path)
        # go to the drives data so that we can get information from the drives
        current_drive_data = current_data['drives']['previous']
        #iterate through the drives in a game
        for drive in current_drive_data:
            # Check if the drive resulted in a safety
            if 'Missed FG' in drive.get('displayResult', ''):
                # Get the team responsible for the safety
                team_responsible = drive.get('team', {}).get('displayName', 'Unknown')
            
                # Update the safety count for the team
                missed_fg_count[team_responsible] = missed_fg_count.get(team_responsible, 0) + 1
except Exception as e:
    print(f"An error occurred: {e}")

print(missed_fg_count['Alabama Crimson Tide'])
# Out:
# 8

# %% [markdown]
# # Get Made FGs

# %%
# create dict to hold team name and number of missed field goals
made_fg_count = {}
#error handling
try:
    # get the key value and file_path from the file and iterate through them
    for game, game_path in all_game_dict.items():
        # get the contents from game file
        current_data = load_json(game_path)
        # go to the drives data so that we can get information from the drives
        current_drive_data = current_data['drives']['previous']
        #iterate through the drives in a game
        for drive in current_drive_data:
            # Check if the drive resulted in a safety
            if 'Field Goal' in drive.get('displayResult', ''):
                # Get the team responsible for the safety
                team_responsible = drive.get('team', {}).get('displayName', 'Unknown')
            
                # Update the safety count for the team
                made_fg_count[team_responsible] = made_fg_count.get(team_responsible, 0) + 1
except Exception as e:
    print(f"An error occurred: {e}")
    
#print Alabama's made fg
print(made_fg_count['Alabama Crimson Tide'])
# Out:
# 18

# %% [markdown]
# # Ratio of Made FGs to Missed FGs

# %%
fg_ratio = {}
try:
    # iterate throguh teams
    for team in made_fg_count:
        #See if they are also in the missed_fg dict and make sure it does not equal zero to avoid division by zero
        if team in missed_fg_count and missed_fg_count[team]!=0:
            #get a ratio of made to missed fgs
            fg_ratio[team] = made_fg_count[team]/missed_fg_count[team]
        #otherwise just return a none value if they aren't in there
        else:
            fg_ratio[team] = None
    #return teams that have a value to a dictionary
    fg_ratio_filtered = {team: ratio for team, ratio in fg_ratio.items() if ratio is not None}
    #print Alabama's ratio
    print(fg_ratio_filtered['Alabama Crimson Tide'])
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# 2.25

# %%
#Get an average ratio for all teams to compate alabama by summing the values in fg_ratio_filtered_dict
total_ratio = sum(fg_ratio_filtered.values())
#divide by length of dictionary to get an average
average_ratio = total_ratio/len(fg_ratio_filtered)
#print the average
print(average_ratio)
# Out:
# 3.223379246324452

# %%
answer_dict['q6'] = "Yes"
answer_dict['q6+1'] = "Alabama wasn't the worst team but their ratio of made field goals to missed field goals was below average. Alabama made 18 and missed 8 field goals which is better than a school like South Carolina who only made 15 but missed 13. In the regular season, Alabama's ratio was 2.25 which is less than the average ratio which was 3.22 though that may include some teams that were only represented in the list once because they are a lower level school. According to the data, Alabama did miss more often than the average school."

# %% [markdown]
# ## Question 7
# A *saftey* in football refers to when the offensive player who has possession of the football is tackled or willingly downs the ball in their end zone. Two points are awared to the defensive team. The offensive team loses possesion of the ball.
#
# In how many games did a safety occur?

# %%
safety_game_count = 0
try:
    #iterate through each game
    for game, game_path in all_game_dict.items():
        #load games
        current_data=load_json(game_path)
        #go to the drives
        current_drive_data = current_data['drives']['previous']
        #set safety value to False
        safety = False
        #iterate through drives
        for drive in current_drive_data:
            #If the result of the drive is a safety, change safety to True and break the for loop
            if 'Safety' in drive.get('displayResult', ''):
                safety = True
                break
        #add one to the counter if a safety occurred
        if safety == True:
            safety_game_count+=1
except Exception as e:
    print(f"An error occurred: {e}")

print(safety_game_count)
# Out:
# 46

# %%
answer_dict['q7'] = safety_game_count

# %% [markdown]
# ## Question 8
# Which team scored the most safeties (include all teams with the same number if tied)?

# %%
#dictionary that keeps track of team and number of safeties against
safety_count = {}
#iterate through games and their files
try:
    for game, game_path in all_game_dict.items():
        #load game
        current_data = load_json(game_path)
        #go to drive information
        current_drive_data = current_data['drives']['previous']
        #iterate through drives in game
        for drive in current_drive_data:
            # Check if the drive resulted in a safety
            if 'Safety' in drive.get('displayResult', ''):
                # Get the team responsible for the safety
                team_against = drive.get('team', {}).get('displayName', 'Unknown')
                if team_against != current_data['teams'][0]['team']['displayName']:
                    team_for = current_data['teams'][0]['team']['displayName']
                else:
                    team_for = current_data['teams'][1]['team']['displayName']
                # Update the safety count for the team
                safety_count[team_for] = safety_count.get(team_for, 0) + 1
except Exception as e:
    print(f"An error occurred: {e}")

#get the maximum value for safeties across all teams
max_safeties = max(safety_count.values())
#create a list to hold teams
most_safeties_for = []
# get key and value pair from team_safety_count
for key, value in safety_count.items():
    #if statement
    if value == max_safeties:
        #
        most_safeties_for.append(key)

# %%
answer_dict["q8"] = most_safeties_for

# %% [markdown]
# ## Question 9
# Which teams (include all, if tied) gave up the most safeties?

# %%
#dictionary that keeps track of team and number of safeties against
team_safety_count = {}
#iterate through games and their files
try:
    for game, game_path in all_game_dict.items():
        #load game
        current_data = load_json(game_path)
        #go to drive information
        current_drive_data = current_data['drives']['previous']
        #iterate through drives in game
        for drive in current_drive_data:
            # Check if the drive resulted in a safety
            if 'Safety' in drive.get('displayResult', ''):
                # Get the team responsible for the safety
                team_responsible = drive.get('team', {}).get('displayName', 'Unknown')
            
                # Update the safety count for the team
                team_safety_count[team_responsible] = team_safety_count.get(team_responsible, 0) + 1
except Exception as e:
    print(f"An error occurred: {e}")
#get the maximum value for safeties across all teams
max_safeties = max(team_safety_count.values())
#create a list to hold teams
most_safeties_teams = []
# get key and value pair from team_safety_count
for key, value in team_safety_count.items():
    #if statement
    if value == max_safeties:
        #
        most_safeties_teams.append(key)

# %%
answer_dict["q9"] = most_safeties_teams

# %% [markdown]
# ## Question 10
# Find the longest play for the 2017 season. (Ex. a 99 yard interception return) If there are several
# of the same length, show them all. Show team matchup, quarter, clocktime, and play text for each of the plays.

# %%
max_yardage = 0
#iterate through files
for game, game_path in all_game_dict.items():
    current_data = load_json(game_path)
    current_drive_data = current_data['drives']['previous']
    # iterates using the drive length
    for i in range(len(current_drive_data)):
        #go to plays
        plays = current_drive_data[i]['plays']
        # iterate over number of plays
        for j in range(len(plays)):
            #continuously append the yardage and determine if it is larger than the current max
            if plays[j]["statYardage"] <= 101 and plays[j]["statYardage"]>max_yardage:
                #make max_yardage the equal to the longest play
                max_yardage = plays[j]["statYardage"]

# %%
longest_play_info = []
# iterate through games
for game, game_path in all_game_dict.items():
    current_data = load_json(game_path)
    current_drive_data = current_data['drives']['previous']
    # iterates through the number of drives
    for i in range(len(current_drive_data)):
        #go to plays
        plays = current_drive_data[i]['plays']
        # iterates through number of plays
        for j in range(len(plays)):
            #if play is equal to max_yardage return team, opponent, quarter, time, and description
            if plays[j]["statYardage"] == max_yardage:
                team = current_drive_data[i]['team']['displayName']
                if team != current_data['teams'][0]['team']['displayName']:
                    opponent = current_data['teams'][0]['team']['displayName']
                else:
                    opponent = current_data['teams'][1]['team']['displayName']
                period = plays[j]["period"]["number"]
                clock = plays[j]["clock"]["displayValue"]
                text = plays[j]["text"]
                info = f"Team: {team}, Opponent: {opponent}, Quarter: {period}, Time: {clock}, Description: {text}"
                longest_play_info.append(info)

# %%
answer_dict["q10"] = longest_play_info

# %% [markdown]
# ## Question 11
# How long were Alabama's FIRST and LAST offensive plays of the season? Provide the description of each play including the yardage.

# %%
#Load first game file
UA_FSU_data = load_json("full/Week 1/400933827 - Alabama vs Florida State.json")
#Load last game file
UA_UGA_data = load_json("full/Bowl/400953415 - Georgia vs Alabama.json")
# get text and yardage from the first offensive play of the first game and last offensive play of their last game
text_1 = UA_FSU_data['drives']['previous'][0]['plays'][1]['text']
yardage_1 = UA_FSU_data['drives']['previous'][0]['plays'][1]['statYardage']
text_2 = UA_UGA_data['drives']['previous'][28]['plays'][1]['text']
yardage_2 = UA_UGA_data['drives']['previous'][28]['plays'][1]['statYardage']

# %%
answer_dict["q11"] = f"Alabama's first drive of the season went for {yardage_1} yards. {text_1}. Alabama's last drive of the season went for {yardage_2} yards. {text_2}."

# %% [markdown]
# ## Question 12
# How many times did Alabama punt in the 2017 season?

# %%
# set a punt counter
punt_count = 0
#error handling
try:
    #iterate through Alabama's game files
    for game, game_path in bama_game_files.items():
        #load json file iteratively
        current_data = load_json(game_path)
        #go to drives
        current_drive_data = current_data['drives']['previous']
        #iterate through the drives in each game
        for drive in current_drive_data:
            #find if result was drive was punt by Alabama and add that to the counter if True
            if 'Punt' in drive.get('displayResult', '') and drive.get('team', {}).get('displayName', '') == 'Alabama Crimson Tide':
                punt_count += 1

except Exception as e:
    print(f"Error {e} occurred")
#print punt_count
print("Alabama's punt count during the season:", punt_count)
# Out:
# Alabama's punt count during the season: 54

# %%
answer_dict["q12"] = punt_count

# %%
try:
    #create json file from dict
    with open("mis501_python_project_asingh26.json", "w") as json_file:
        json.dump(answer_dict, json_file, indent=4)
except Exception as e:
    print(f"Error {e} occurred")
